# %% [markdown]
# ### Group Members

# %% [raw]
# 1- Muneeza Baig CS-19015
# 2- Zuhaira Abdullah Siddiqui CS-19019
# 3- Syeda Ghazia Hashmi CS-19061

# %% [markdown]
# # Imports

# %%
#all the imports are listed below. 
import numpy as np
import pandas as pd
from numpy import asarray
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from tensorflow.keras import models
from tensorflow.keras import layers

# %% [markdown]
# # Reading the dataset - Grades_Dataset.csv

# %%
# Reading the dataset.
data = pd.read_csv('The_Grades_Dataset.csv')

# Displaying the Head (Column Names) and '3' rows 
data.head(3)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
#
# [3 rows x 43 columns]

# %%
# Seeking the unique values present in the dataset


# print(data['CS-318'].unique())
# print(data['MT-222'].unique())
# print(data['CS-406'].unique())

# %% [raw]
# Thus, we have the following features values :
# 'A+' 'A-' 'A' 'B-' 'B' 'B+' 'C+' 'C-' 'C' 'D' 'D+' 'D-' 'F' 'W' 'WU' 'I' nan
#
# Now, we have to remove the Nan value from the dataset.
#
# we are filling or replacing all the Nan values with mode values.

# %% [markdown]
# ## Data preprocessing Steps.

# %% [raw]
# 1- Treating Null Values
# 2- Ordinal Encoding
# 3- Skewness of Dataset
# 4- P-Value Significance

# %%
#displaying the count of null values present in each column. 

# data.isnull().sum()

# %%
#list will return the features that have null values
features_with_null = [features for features in data if data[features].isnull().sum()]
for each_feature in features_with_null:
    data[each_feature] = data[each_feature].fillna(data[each_feature].mode()[0]) #filling each null value present in each column with mode value of its column iteratively.

# %%
#displaying the count of null values present in each column. The count must be zero now. 

# data.isnull().sum()

# %% [raw]
# Now, we can see we have zero null values in each column.

# %%
#Storing the updated data to the csv file. 
data.to_csv('The_Grades_Dataset_Clean.csv')
data = pd.read_csv('The_Grades_Dataset_Clean.csv')
# data

# %%
#Dropping the unnecessary columns from dataset.
data.drop(['Seat No.','Unnamed: 0'], axis=1, inplace=True)
# data

# %% [markdown]
# ### Ordinal Encoding

# %% [raw]
# Next, we convert string data into integer data. we have a natural ranking for grades, hence we can opt for ordinal encoding

# %%
#Seperating the inputs and outputs, so to apply encoding on feature values only. 
Predictors=data.drop("CGPA", axis=1)
target=data["CGPA"]
# print(Predictors)
# print(target)

# %%
#Replacing the string values with integer values with respect to their weightage on CGPA
list(Predictors.columns.values)
Col_list=list(Predictors.columns)
# print(Col_list)
for Col in Col_list:
    Predictors[Col]=Predictors[Col].replace('A+',4.0)
    Predictors[Col]=Predictors[Col].replace('A',4.0)
    Predictors[Col]=Predictors[Col].replace('A-',3.7)
    Predictors[Col]=Predictors[Col].replace('B+',3.4)
    Predictors[Col]=Predictors[Col].replace('B',3.0)
    Predictors[Col]=Predictors[Col].replace('B-',2.7)
    Predictors[Col]=Predictors[Col].replace('C+',2.4)
    Predictors[Col]=Predictors[Col].replace('C',2.0)
    Predictors[Col]=Predictors[Col].replace('C-',1.7)
    Predictors[Col]=Predictors[Col].replace('D+',1.4)
    Predictors[Col]=Predictors[Col].replace('D',1.0)
    Predictors[Col]=Predictors[Col].replace('F',0.0)
    Predictors[Col]=Predictors[Col].replace('WU',0.0)
    Predictors[Col]=Predictors[Col].replace('W',0.0)
    Predictors[Col]=Predictors[Col].replace('I',0.0)
    
#Displaying the datatype of each columns.
# type(Predictors)
# Predictors.info()

# %% [raw]
# Here we are going to check whether our dataset is linear or not.

# %%
sns.set_theme(); np.random.seed(0)
ax = sns.distplot(Predictors)
# Out:
# E:\Programs\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [raw]
# The nature of dataset is non-linear.

# %% [markdown]
# ### Skewness of Dataset.

# %%
from scipy.stats import skew
feature_skewness=skew(Predictors, axis=0, bias=True)
print(feature_skewness)
pos_count, neg_count = 0, 0  
# iterating each number in list
for num in feature_skewness:
      
    # checking condition
    if num >= 0:
        pos_count += 1
  
    else:
        neg_count += 1
# print("Positive numbers ", pos_count)
# print("Negative numbers ", neg_count)
# Out:
# [-0.88148598 -0.22711828 -1.39018879 -0.58713849 -0.83153589 -1.27153168
#  -0.96794495 -0.82802766 -0.78454195 -0.38067705 -0.65114686 -1.48758566
#  -0.40317514 -1.14052767 -0.67625631 -1.09321583 -0.3336205  -0.54286876
#  -0.12538856 -1.07201324 -0.61959461 -0.37037819 -0.93371456 -0.34728185
#  -0.82499225 -0.65395206 -0.97988792 -0.52339715 -1.26771782 -0.84492034
#  -0.66370123 -0.79671355 -0.546503   -0.41903604 -0.77760205 -0.57648341
#  -2.11671195 -2.15999595 -0.84501684 -0.87423662 -2.08398634]

# %% [raw]
# We can see we have neg_count more than pos_count, indicating dataset is positive skewed, unbalanced.

# %% [markdown]
# ### Square Root Transformation - Treating Imbalanced Dataset

# %%
# from scipy.stats import skew
# Predictors_sqrt = np.sqrt(Predictors)
# feature_skewness=skew(Predictors_sqrt, axis=0, bias=True)
# print(feature_skewness)
# pos_count, neg_count = 0, 0  
# # iterating each number in list
# for num in feature_skewness:
      
#     # checking condition
#     if num >= 0:
#         pos_count += 1
  
#     else:
#         neg_count += 1
# print("Positive numbers ", pos_count)
# print("Negative numbers ", neg_count)

# %% [markdown]
# ### Significance of Features - P_Value

# %%
X_incl_const = sm.add_constant(Predictors)

alternate_model = sm.OLS(target, X_incl_const)
results = alternate_model.fit()
#Finding p-values
features_P_value = pd.DataFrame({'p-value': round(results.pvalues, 3)})
features_P_value = features_P_value[features_P_value<0.05]

#dropping insignificant p values. All the listed values have significant features. 
features_P_value=features_P_value.dropna()
# features_P_value

# %% [markdown]
# #### NOTE :

# %% [raw]
# The features that are significant have value less than 0.05 which are listed above. Due to the scope of our problem, we can not remove the insignificant values, as every feature(Subject) has an impact on the CGPA of a student. If the credit hour infromation would have been given, then we could reduce the importance of feature using Ridge regularization which makes the value small rather than making it zero.

# %% [markdown]
# ## 2. Implementation of Models.

# %% [raw]
# Model 1: predict final CGPA based on GPs of first year only.
# Model 2: predict final CGPA based on GPs of first two years.
# Model 3: predict final CGPA based on GPs of first three years.
#
# For each model, implementing the following machine learning algorithms.
#
# 1- Linear Regression.
#
# 2- Regression Tree.
#
# 3- ANN
#
# 4- Polynomial Regression

# %% [markdown]
# # Model 1

# %% [raw]
# Algo 1 - Linear Regression.
# Algo 2 - Regression Tree.
# Algo 3 - Neural Networks.
# Algo 4 - Polynomial Regression.

# %%
Predictor_M1=Predictors.iloc[0:571,0:11] #Slicing
target=data["CGPA"]
# Predictor_M1.head(3) # Only 1st year Grades.

# %% [markdown]
# #### Cross-Validation - Leave one out technique

# %%
# from sklearn.model_selection import LeaveOneOut

# X = [1, 2, 3, 4]
# loo = LeaveOneOut()
# for train, test in loo.split(X):
#     print("%s %s" % (Predictor_M1, target))

# %% [markdown]
# ### Algorithm no. 01 - Linear Regression

# %%
X_train_M1_lr,X_test_M1_lr,Y_train_M1_lr,Y_test_M1_lr = train_test_split(Predictor_M1, target,test_size=0.2,random_state=0) # Implementing 80 and 20 split
r1=LinearRegression()
r1.fit(X_train_M1_lr,Y_train_M1_lr)


# print("The training accuracy", r1.score(X_train_M1_lr,Y_train_M1_lr))
# print("The testing accuracy",r1.score(X_test_M1_lr,Y_test_M1_lr))
# Out:
# LinearRegression()

# %% [markdown]
# ### Algorithm no. 02 - Regression Tree

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M1, target, test_size=0.3)
rt = DecisionTreeRegressor(criterion = 'mse', max_depth=5)
model_r = rt.fit(X_train, y_train)
y_test_pred = model_r.predict(X_test)
y_train_pred = model_r.predict(X_train)

# print('R Squared Score of train is:', r2_score(y_train, y_train_pred))
# print('R Squared Score of test is:', r2_score(y_test, y_test_pred))
# Out:
# E:\Programs\Python310\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# ### Algorithm no. 03 - ANN

# %%
X_train_a1, X_test_a1, y_train_a1, y_test_a1 = train_test_split(Predictor_M1, target)
model_a1=models.Sequential()
model_a1.add(layers.Dense(64,activation='relu', input_shape=(X_train_a1.shape[1],)))
model_a1.add(layers.Dense(64,activation='relu'))
model_a1.add(layers.Dense(64,activation='relu'))
model_a1.add(layers.Dense(1,activation='linear'))
model_a1.compile(loss='mean_squared_error',optimizer='adam', metrics=['mean_absolute_error','mean_squared_error'])
history = model_a1.fit(X_train_a1,y_train_a1,epochs=100, batch_size=10, validation_data=(X_test_a1, y_test_a1))
# Out:
# Epoch 1/100
# 43/43 [==============================] - 1s 6ms/step - loss: 1.2759 - mean_absolute_error: 0.7791 - mean_squared_error: 1.2759 - val_loss: 0.1401 - val_mean_absolute_error: 0.3082 - val_mean_squared_error: 0.1401
# Epoch 2/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0978 - mean_absolute_error: 0.2483 - mean_squared_error: 0.0978 - val_loss: 0.0780 - val_mean_absolute_error: 0.2201 - val_mean_squared_error: 0.0780
# Epoch 3/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0708 - mean_absolute_error: 0.2044 - mean_squared_error: 0.0708 - val_loss: 0.0725 - val_mean_absolute_error: 0.2015 - val_mean_squared_error: 0.0725
# Epoch 4/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0624 - mean_absolute_error: 0.1951 - mean_squared_error: 0.0624 - val_loss: 0.0662 - val_mean_absolute_error: 0.1929 - val_mean_squared_error: 0.0662
# Epoch 5/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0652 - mean_absolute_error: 0.2037 - mean_squared_error: 0.0652 - val_loss: 0.0646 - val_mean_absolute_error: 0.1880 - val_mean_squared_error: 0.0646
# Epoch 6/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0579 - mean_absolute_error: 0.1898 - mean_squared_error: 0.0579 - val_loss: 0.0624 - val_mean_absolute_error: 0.1828 - val_mean_squared_error: 0.0624
# Epoch 7/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0546 - mean_absolute_error: 0.1851 - mean_squared_error: 0.0546 - val_loss: 0.0782 - val_mean_absolute_error: 0.2200 - val_mean_squared_error: 0.0782
# Epoch 8/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0565 - mean_absolute_error: 0.1889 - mean_squared_error: 0.0565 - val_loss: 0.0621 - val_mean_absolute_error: 0.1824 - val_mean_squared_error: 0.0621
# Epoch 9/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0525 - mean_absolute_error: 0.1836 - mean_squared_error: 0.0525 - val_loss: 0.0654 - val_mean_absolute_error: 0.1891 - val_mean_squared_error: 0.0654
# Epoch 10/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0526 - mean_absolute_error: 0.1845 - mean_squared_error: 0.0526 - val_loss: 0.0673 - val_mean_absolute_error: 0.1791 - val_mean_squared_error: 0.0673
# Epoch 11/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0482 - mean_absolute_error: 0.1756 - mean_squared_error: 0.0482 - val_loss: 0.0709 - val_mean_absolute_error: 0.1991 - val_mean_squared_error: 0.0709
# Epoch 12/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0526 - mean_absolute_error: 0.1841 - mean_squared_error: 0.0526 - val_loss: 0.0655 - val_mean_absolute_error: 0.1852 - val_mean_squared_error: 0.0655
# Epoch 13/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0547 - mean_absolute_error: 0.1880 - mean_squared_error: 0.0547 - val_loss: 0.0645 - val_mean_absolute_error: 0.1863 - val_mean_squared_error: 0.0645
# Epoch 14/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0479 - mean_absolute_error: 0.1746 - mean_squared_error: 0.0479 - val_loss: 0.0641 - val_mean_absolute_error: 0.1746 - val_mean_squared_error: 0.0641
# Epoch 15/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0451 - mean_absolute_error: 0.1670 - mean_squared_error: 0.0451 - val_loss: 0.0758 - val_mean_absolute_error: 0.2130 - val_mean_squared_error: 0.0758
# Epoch 16/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0468 - mean_absolute_error: 0.1712 - mean_squared_error: 0.0468 - val_loss: 0.0694 - val_mean_absolute_error: 0.1933 - val_mean_squared_error: 0.0694
# Epoch 17/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0468 - mean_absolute_error: 0.1713 - mean_squared_error: 0.0468 - val_loss: 0.0692 - val_mean_absolute_error: 0.1879 - val_mean_squared_error: 0.0692
# Epoch 18/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0425 - mean_absolute_error: 0.1635 - mean_squared_error: 0.0425 - val_loss: 0.0820 - val_mean_absolute_error: 0.2001 - val_mean_squared_error: 0.0820
# Epoch 19/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0470 - mean_absolute_error: 0.1745 - mean_squared_error: 0.0470 - val_loss: 0.0664 - val_mean_absolute_error: 0.1748 - val_mean_squared_error: 0.0664
# Epoch 20/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0409 - mean_absolute_error: 0.1608 - mean_squared_error: 0.0409 - val_loss: 0.0694 - val_mean_absolute_error: 0.1840 - val_mean_squared_error: 0.0694
# Epoch 21/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0440 - mean_absolute_error: 0.1651 - mean_squared_error: 0.0440 - val_loss: 0.0949 - val_mean_absolute_error: 0.2442 - val_mean_squared_error: 0.0949
# Epoch 22/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0495 - mean_absolute_error: 0.1800 - mean_squared_error: 0.0495 - val_loss: 0.0756 - val_mean_absolute_error: 0.1882 - val_mean_squared_error: 0.0756
# Epoch 23/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0424 - mean_absolute_error: 0.1655 - mean_squared_error: 0.0424 - val_loss: 0.0690 - val_mean_absolute_error: 0.1845 - val_mean_squared_error: 0.0690
# Epoch 24/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0405 - mean_absolute_error: 0.1594 - mean_squared_error: 0.0405 - val_loss: 0.0697 - val_mean_absolute_error: 0.1823 - val_mean_squared_error: 0.0697
# Epoch 25/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0431 - mean_absolute_error: 0.1616 - mean_squared_error: 0.0431 - val_loss: 0.0695 - val_mean_absolute_error: 0.1915 - val_mean_squared_error: 0.0695
# Epoch 26/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0437 - mean_absolute_error: 0.1665 - mean_squared_error: 0.0437 - val_loss: 0.0749 - val_mean_absolute_error: 0.2000 - val_mean_squared_error: 0.0749
# Epoch 27/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0387 - mean_absolute_error: 0.1557 - mean_squared_error: 0.0387 - val_loss: 0.0746 - val_mean_absolute_error: 0.1910 - val_mean_squared_error: 0.0746
# Epoch 28/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0373 - mean_absolute_error: 0.1530 - mean_squared_error: 0.0373 - val_loss: 0.0824 - val_mean_absolute_error: 0.2159 - val_mean_squared_error: 0.0824
# Epoch 29/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0387 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0387 - val_loss: 0.0692 - val_mean_absolute_error: 0.1825 - val_mean_squared_error: 0.0692
# Epoch 30/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0399 - mean_absolute_error: 0.1569 - mean_squared_error: 0.0399 - val_loss: 0.0770 - val_mean_absolute_error: 0.2014 - val_mean_squared_error: 0.0770
# Epoch 31/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0481 - mean_absolute_error: 0.1739 - mean_squared_error: 0.0481 - val_loss: 0.0753 - val_mean_absolute_error: 0.1907 - val_mean_squared_error: 0.0753
# Epoch 32/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_absolute_error: 0.1552 - mean_squared_error: 0.0386 - val_loss: 0.0721 - val_mean_absolute_error: 0.1913 - val_mean_squared_error: 0.0721
# Epoch 33/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0372 - mean_absolute_error: 0.1523 - mean_squared_error: 0.0372 - val_loss: 0.0726 - val_mean_absolute_error: 0.1925 - val_mean_squared_error: 0.0726
# Epoch 34/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0392 - mean_absolute_error: 0.1559 - mean_squared_error: 0.0392 - val_loss: 0.0731 - val_mean_absolute_error: 0.1866 - val_mean_squared_error: 0.0731
# Epoch 35/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0431 - mean_absolute_error: 0.1636 - mean_squared_error: 0.0431 - val_loss: 0.0769 - val_mean_absolute_error: 0.2020 - val_mean_squared_error: 0.0769
# Epoch 36/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0412 - mean_absolute_error: 0.1620 - mean_squared_error: 0.0412 - val_loss: 0.0733 - val_mean_absolute_error: 0.1900 - val_mean_squared_error: 0.0733
# Epoch 37/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0353 - mean_absolute_error: 0.1484 - mean_squared_error: 0.0353 - val_loss: 0.0821 - val_mean_absolute_error: 0.1924 - val_mean_squared_error: 0.0821
# Epoch 38/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0355 - mean_absolute_error: 0.1460 - mean_squared_error: 0.0355 - val_loss: 0.0715 - val_mean_absolute_error: 0.1870 - val_mean_squared_error: 0.0715
# Epoch 39/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0382 - mean_absolute_error: 0.1534 - mean_squared_error: 0.0382 - val_loss: 0.0755 - val_mean_absolute_error: 0.1874 - val_mean_squared_error: 0.0755
# Epoch 40/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0348 - mean_absolute_error: 0.1474 - mean_squared_error: 0.0348 - val_loss: 0.0764 - val_mean_absolute_error: 0.1884 - val_mean_squared_error: 0.0764
# Epoch 41/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0345 - mean_absolute_error: 0.1431 - mean_squared_error: 0.0345 - val_loss: 0.0875 - val_mean_absolute_error: 0.2064 - val_mean_squared_error: 0.0875
# Epoch 42/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0411 - mean_absolute_error: 0.1558 - mean_squared_error: 0.0411 - val_loss: 0.0804 - val_mean_absolute_error: 0.2033 - val_mean_squared_error: 0.0804
# Epoch 43/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0357 - mean_absolute_error: 0.1477 - mean_squared_error: 0.0357 - val_loss: 0.0710 - val_mean_absolute_error: 0.1847 - val_mean_squared_error: 0.0710
# Epoch 44/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0352 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0352 - val_loss: 0.0757 - val_mean_absolute_error: 0.1889 - val_mean_squared_error: 0.0757
# Epoch 45/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0395 - mean_absolute_error: 0.1555 - mean_squared_error: 0.0395 - val_loss: 0.0700 - val_mean_absolute_error: 0.1784 - val_mean_squared_error: 0.0700
# Epoch 46/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0385 - mean_absolute_error: 0.1547 - mean_squared_error: 0.0385 - val_loss: 0.0714 - val_mean_absolute_error: 0.1821 - val_mean_squared_error: 0.0714
# Epoch 47/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0359 - mean_absolute_error: 0.1476 - mean_squared_error: 0.0359 - val_loss: 0.0743 - val_mean_absolute_error: 0.1823 - val_mean_squared_error: 0.0743
# Epoch 48/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0384 - mean_absolute_error: 0.1515 - mean_squared_error: 0.0384 - val_loss: 0.0736 - val_mean_absolute_error: 0.1895 - val_mean_squared_error: 0.0736
# Epoch 49/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0335 - mean_absolute_error: 0.1418 - mean_squared_error: 0.0335 - val_loss: 0.0721 - val_mean_absolute_error: 0.1915 - val_mean_squared_error: 0.0721
# Epoch 50/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0325 - mean_absolute_error: 0.1391 - mean_squared_error: 0.0325 - val_loss: 0.0799 - val_mean_absolute_error: 0.2103 - val_mean_squared_error: 0.0799
# Epoch 51/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0315 - mean_absolute_error: 0.1375 - mean_squared_error: 0.0315 - val_loss: 0.0738 - val_mean_absolute_error: 0.1996 - val_mean_squared_error: 0.0738
# Epoch 52/100
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0338 - mean_absolute_error: 0.1398 - mean_squared_error: 0.0338 - val_loss: 0.0730 - val_mean_absolute_error: 0.1890 - val_mean_squared_error: 0.0730
# Epoch 53/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0310 - mean_absolute_error: 0.1357 - mean_squared_error: 0.0310 - val_loss: 0.0715 - val_mean_absolute_error: 0.1836 - val_mean_squared_error: 0.0715
# Epoch 54/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0306 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0306 - val_loss: 0.0750 - val_mean_absolute_error: 0.1876 - val_mean_squared_error: 0.0750
# Epoch 55/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0395 - mean_absolute_error: 0.1540 - mean_squared_error: 0.0395 - val_loss: 0.0895 - val_mean_absolute_error: 0.2025 - val_mean_squared_error: 0.0895
# Epoch 56/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0345 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0345 - val_loss: 0.0794 - val_mean_absolute_error: 0.1879 - val_mean_squared_error: 0.0794
# Epoch 57/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0288 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0288 - val_loss: 0.0740 - val_mean_absolute_error: 0.1925 - val_mean_squared_error: 0.0740
# Epoch 58/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0280 - mean_absolute_error: 0.1297 - mean_squared_error: 0.0280 - val_loss: 0.0806 - val_mean_absolute_error: 0.1939 - val_mean_squared_error: 0.0806
# Epoch 59/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0292 - mean_absolute_error: 0.1315 - mean_squared_error: 0.0292 - val_loss: 0.0791 - val_mean_absolute_error: 0.2030 - val_mean_squared_error: 0.0791
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0345 - mean_absolute_error: 0.1455 - mean_squared_error: 0.0345 - val_loss: 0.0743 - val_mean_absolute_error: 0.1834 - val_mean_squared_error: 0.0743
# Epoch 61/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0407 - mean_absolute_error: 0.1577 - mean_squared_error: 0.0407 - val_loss: 0.0792 - val_mean_absolute_error: 0.2029 - val_mean_squared_error: 0.0792
# Epoch 62/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0313 - mean_absolute_error: 0.1336 - mean_squared_error: 0.0313 - val_loss: 0.1009 - val_mean_absolute_error: 0.2470 - val_mean_squared_error: 0.1009
# Epoch 63/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0362 - mean_absolute_error: 0.1469 - mean_squared_error: 0.0362 - val_loss: 0.0735 - val_mean_absolute_error: 0.1914 - val_mean_squared_error: 0.0735
# Epoch 64/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0286 - mean_absolute_error: 0.1300 - mean_squared_error: 0.0286 - val_loss: 0.0804 - val_mean_absolute_error: 0.2107 - val_mean_squared_error: 0.0804
# Epoch 65/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0303 - mean_absolute_error: 0.1339 - mean_squared_error: 0.0303 - val_loss: 0.0774 - val_mean_absolute_error: 0.2013 - val_mean_squared_error: 0.0774
# Epoch 66/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0298 - mean_absolute_error: 0.1350 - mean_squared_error: 0.0298 - val_loss: 0.0817 - val_mean_absolute_error: 0.1953 - val_mean_squared_error: 0.0817
# Epoch 67/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0283 - mean_absolute_error: 0.1295 - mean_squared_error: 0.0283 - val_loss: 0.0778 - val_mean_absolute_error: 0.1887 - val_mean_squared_error: 0.0778
# Epoch 68/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0288 - mean_absolute_error: 0.1286 - mean_squared_error: 0.0288 - val_loss: 0.0806 - val_mean_absolute_error: 0.1901 - val_mean_squared_error: 0.0806
# Epoch 69/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0261 - mean_absolute_error: 0.1238 - mean_squared_error: 0.0261 - val_loss: 0.0822 - val_mean_absolute_error: 0.2090 - val_mean_squared_error: 0.0822
# Epoch 70/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0273 - mean_absolute_error: 0.1283 - mean_squared_error: 0.0273 - val_loss: 0.0795 - val_mean_absolute_error: 0.2046 - val_mean_squared_error: 0.0795
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0293 - mean_absolute_error: 0.1325 - mean_squared_error: 0.0293 - val_loss: 0.1003 - val_mean_absolute_error: 0.2474 - val_mean_squared_error: 0.1003
# Epoch 72/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0279 - mean_absolute_error: 0.1296 - mean_squared_error: 0.0279 - val_loss: 0.0797 - val_mean_absolute_error: 0.2031 - val_mean_squared_error: 0.0797
# Epoch 73/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0252 - mean_absolute_error: 0.1200 - mean_squared_error: 0.0252 - val_loss: 0.0857 - val_mean_absolute_error: 0.2028 - val_mean_squared_error: 0.0857
# Epoch 74/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0264 - mean_absolute_error: 0.1226 - mean_squared_error: 0.0264 - val_loss: 0.0782 - val_mean_absolute_error: 0.1948 - val_mean_squared_error: 0.0782
# Epoch 75/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0255 - mean_absolute_error: 0.1222 - mean_squared_error: 0.0255 - val_loss: 0.0798 - val_mean_absolute_error: 0.1945 - val_mean_squared_error: 0.0798
# Epoch 76/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0331 - mean_absolute_error: 0.1429 - mean_squared_error: 0.0331 - val_loss: 0.0846 - val_mean_absolute_error: 0.2080 - val_mean_squared_error: 0.0846
# Epoch 77/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0359 - mean_absolute_error: 0.1482 - mean_squared_error: 0.0359 - val_loss: 0.0843 - val_mean_absolute_error: 0.2064 - val_mean_squared_error: 0.0843
# Epoch 78/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0281 - mean_absolute_error: 0.1293 - mean_squared_error: 0.0281 - val_loss: 0.0814 - val_mean_absolute_error: 0.2064 - val_mean_squared_error: 0.0814
# Epoch 79/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0267 - mean_absolute_error: 0.1244 - mean_squared_error: 0.0267 - val_loss: 0.0789 - val_mean_absolute_error: 0.1957 - val_mean_squared_error: 0.0789
# Epoch 80/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0252 - mean_absolute_error: 0.1202 - mean_squared_error: 0.0252 - val_loss: 0.0828 - val_mean_absolute_error: 0.1976 - val_mean_squared_error: 0.0828
# Epoch 81/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0216 - mean_absolute_error: 0.1097 - mean_squared_error: 0.0216 - val_loss: 0.0874 - val_mean_absolute_error: 0.2090 - val_mean_squared_error: 0.0874
# Epoch 82/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0243 - mean_absolute_error: 0.1174 - mean_squared_error: 0.0243 - val_loss: 0.0863 - val_mean_absolute_error: 0.2041 - val_mean_squared_error: 0.0863
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0255 - mean_absolute_error: 0.1245 - mean_squared_error: 0.0255 - val_loss: 0.0823 - val_mean_absolute_error: 0.1953 - val_mean_squared_error: 0.0823
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0249 - mean_absolute_error: 0.1193 - mean_squared_error: 0.0249 - val_loss: 0.0832 - val_mean_absolute_error: 0.1960 - val_mean_squared_error: 0.0832
# Epoch 85/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0220 - mean_absolute_error: 0.1123 - mean_squared_error: 0.0220 - val_loss: 0.0979 - val_mean_absolute_error: 0.2385 - val_mean_squared_error: 0.0979
# Epoch 86/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0305 - mean_absolute_error: 0.1358 - mean_squared_error: 0.0305 - val_loss: 0.0858 - val_mean_absolute_error: 0.2175 - val_mean_squared_error: 0.0858
# Epoch 87/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0240 - mean_absolute_error: 0.1131 - mean_squared_error: 0.0240 - val_loss: 0.0831 - val_mean_absolute_error: 0.1969 - val_mean_squared_error: 0.0831
# Epoch 88/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0258 - mean_absolute_error: 0.1227 - mean_squared_error: 0.0258 - val_loss: 0.0860 - val_mean_absolute_error: 0.2216 - val_mean_squared_error: 0.0860
# Epoch 89/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0220 - mean_absolute_error: 0.1127 - mean_squared_error: 0.0220 - val_loss: 0.0849 - val_mean_absolute_error: 0.2110 - val_mean_squared_error: 0.0849
# Epoch 90/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0279 - mean_absolute_error: 0.1295 - mean_squared_error: 0.0279 - val_loss: 0.0883 - val_mean_absolute_error: 0.2091 - val_mean_squared_error: 0.0883
# Epoch 91/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0277 - mean_absolute_error: 0.1307 - mean_squared_error: 0.0277 - val_loss: 0.0842 - val_mean_absolute_error: 0.2019 - val_mean_squared_error: 0.0842
# Epoch 92/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0247 - mean_absolute_error: 0.1195 - mean_squared_error: 0.0247 - val_loss: 0.1007 - val_mean_absolute_error: 0.2413 - val_mean_squared_error: 0.1007
# Epoch 93/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0320 - mean_absolute_error: 0.1396 - mean_squared_error: 0.0320 - val_loss: 0.0874 - val_mean_absolute_error: 0.2104 - val_mean_squared_error: 0.0874
# Epoch 94/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0257 - mean_absolute_error: 0.1212 - mean_squared_error: 0.0257 - val_loss: 0.0812 - val_mean_absolute_error: 0.2009 - val_mean_squared_error: 0.0812
# Epoch 95/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0206 - mean_absolute_error: 0.1082 - mean_squared_error: 0.0206 - val_loss: 0.0908 - val_mean_absolute_error: 0.2059 - val_mean_squared_error: 0.0908
# Epoch 96/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0257 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0257 - val_loss: 0.0827 - val_mean_absolute_error: 0.2063 - val_mean_squared_error: 0.0827
# Epoch 97/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0211 - mean_absolute_error: 0.1099 - mean_squared_error: 0.0211 - val_loss: 0.0932 - val_mean_absolute_error: 0.2213 - val_mean_squared_error: 0.0932
# Epoch 98/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0194 - mean_absolute_error: 0.1015 - mean_squared_error: 0.0194 - val_loss: 0.0878 - val_mean_absolute_error: 0.2050 - val_mean_squared_error: 0.0878
# Epoch 99/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0199 - mean_absolute_error: 0.1031 - mean_squared_error: 0.0199 - val_loss: 0.1047 - val_mean_absolute_error: 0.2409 - val_mean_squared_error: 0.1047
# Epoch 100/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_absolute_error: 0.1138 - mean_squared_error: 0.0229 - val_loss: 0.0833 - val_mean_absolute_error: 0.2053 - val_mean_squared_error: 0.0833

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.xlabel("Epochs")
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.show()

# %%
test_predictions=model.predict(X_test)
model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 0s 6ms/step
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0891 - mean_absolute_error: 0.2389 - mean_squared_error: 0.0891
# [0.0890941321849823, 0.23886939883232117, 0.0890941321849823]

# %% [markdown]
# ### Algorithm no. 04 - Polynomial Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M1, target, test_size=0.2, random_state=10)
deg=2 # Degree 9 is giving the error of insufficient memory
X_train_poly2=PolynomialFeatures(degree=deg).fit_transform(X_train)
X_train_poly2=pd.DataFrame(X_train_poly2)
X_train_poly2=X_train_poly2.drop([0],axis=1)
model5=LinearRegression()
model5.fit(X_train_poly2,y_train)

print('Training data r-square:', model5.score(X_train_poly2, y_train))
X_test_poly2=PolynomialFeatures(degree=deg).fit_transform(X_test)
X_test_poly2=pd.DataFrame(X_test_poly2)
X_test_poly2=X_test_poly2.drop([0],axis=1)
print('Test data r-square:', model5.score(X_test_poly2, y_test))
# print('Number of non-zero features:',np.sum(model5.coef_ != 0))
# Out:
# Training data r-square: 0.9083469239333103
# Test data r-square: 0.792020371849271

# %% [markdown]
# # Model 2

# %%
Predictor_M2=Predictors.iloc[0:571,0:22] #Slicing
Predictor_M2 # Only 1st & 2nd year Grades.
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0       2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7
# 1       4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0
# 2       4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4
# 3       1.0     2.4     1.4        1.0     1.0     3.7     1.4     1.7
# 4       3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566     3.0     4.0     4.0        3.7     4.0     4.0     3.7     3.7
# 567     4.0     4.0     4.0        4.0     4.0     4.0     4.0     3.7
# 568     3.0     4.0     3.7        3.4     4.0     4.0     4.0     4.0
# 569     4.0     3.4     1.0        4.0     1.0     1.4     2.7     1.7
# 570     2.0     1.0     1.0        2.0     2.0     1.4     3.0     2.4
#
#      EE-119  ME-107  ...  MT-222  EE-222  MT-224  CS-210  CS-211  CS-203  \
# 0       2.7     1.7  ...     1.0     3.7     2.7     2.4     1.4     1.4
# 1       1.4     1.0  ...     2.7     1.7     1.4     1.4     1.0     2.0
# 2       3.7     3.7  ...     4.0     4.0     4.0     4.0     4.0     4.0
# 3       1.0     2.4  ...     1.4     2.7     1.0     2.0     3.4     2.4
# 4       4.0     3.7  ...     4.0     3.7     3.7     3.7     2.7     4.0
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 566     4.0     3.4  ...     4.0     4.0     4.0     4.0     4.0     4.0
# 567     4.0     4.0  ...     2.4     3.7     3.0     4.0     4.0     4.0
# 568     4.0     3.0  ...     3.0     3.4     3.0     3.7     4.0     3.4
# 569     2.7     1.7  ...     1.0     1.0     3.0     2.7     3.0     2.7
# 570     2.0     1.4  ...     1.7     3.4     1.4     3.4     1.7     3.0
#
#      CS-214  EE-217  CS-212  CS-215
# 0       1.0     4.0     1.0     1.7
# 1       1.0     2.7     2.0     1.0
# 2       3.7     4.0     3.7     4.0
# 3       1.0     1.4     1.0     1.0
# 4       3.7     4.0     3.7     3.7
# ..      ...     ...     ...     ...
# 566     4.0     4.0     3.0     3.7
# 567     4.0     4.0     4.0     3.0
# 568     3.0     4.0     3.4     3.0
# 569     2.0     2.7     1.4     1.4
# 570     1.4     1.7     2.0     1.4
#
# [571 rows x 22 columns]

# %% [markdown]
# ### Algorithm no. 01 - Linear Regression

# %%
X_train_M2_lr,X_test_M2_lr,Y_train_M2_lr,Y_test_M2_lr = train_test_split(Predictor_M2, target,test_size=0.2,random_state=0) # Implementing 80 and 20 split
r2=LinearRegression()
r2.fit(X_train_M2_lr,Y_train_M2_lr)
print("The training accuracy", r2.score(X_train_M2_lr,Y_train_M2_lr))
print("The testing accuracy",r2.score(X_test_M2_lr,Y_test_M2_lr))
# Out:
# The training accuracy 0.9088336931042303
# The testing accuracy 0.9066851498286942

# %% [markdown]
# ### Algorithm no. 02 - Regression Tree

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M2, target, test_size=0.3)
rt = DecisionTreeRegressor(criterion = 'mse', max_depth=5)
model_r = rt.fit(X_train, y_train)
y_test_pred = model_r.predict(X_test)
y_train_pred = model_r.predict(X_train)
print('R Squared Score of train is:', r2_score(y_train, y_train_pred))
print('R Squared Score of test is:', r2_score(y_test, y_test_pred))
# Out:
# R Squared Score of train is: 0.9139968363190603
# R Squared Score of test is: 0.7526311054543646
# E:\Programs\Python310\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# ### Algorithm no. 03 - ANN

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M2, target)
model=models.Sequential()
model.add(layers.Dense(64,activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(1,activation='linear'))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['mean_absolute_error','mean_squared_error'])
history = model.fit(X_train,y_train,epochs=100, batch_size=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 43/43 [==============================] - 1s 6ms/step - loss: 0.5792 - mean_absolute_error: 0.4987 - mean_squared_error: 0.5792 - val_loss: 0.0685 - val_mean_absolute_error: 0.1802 - val_mean_squared_error: 0.0685
# Epoch 2/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0525 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0525 - val_loss: 0.0566 - val_mean_absolute_error: 0.1558 - val_mean_squared_error: 0.0566
# Epoch 3/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0448 - mean_absolute_error: 0.1562 - mean_squared_error: 0.0448 - val_loss: 0.0506 - val_mean_absolute_error: 0.1413 - val_mean_squared_error: 0.0506
# Epoch 4/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0384 - mean_absolute_error: 0.1438 - mean_squared_error: 0.0384 - val_loss: 0.0486 - val_mean_absolute_error: 0.1390 - val_mean_squared_error: 0.0486
# Epoch 5/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0327 - mean_absolute_error: 0.1324 - mean_squared_error: 0.0327 - val_loss: 0.0402 - val_mean_absolute_error: 0.1193 - val_mean_squared_error: 0.0402
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0295 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0295 - val_loss: 0.0388 - val_mean_absolute_error: 0.1190 - val_mean_squared_error: 0.0388
# Epoch 7/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0292 - mean_absolute_error: 0.1287 - mean_squared_error: 0.0292 - val_loss: 0.0540 - val_mean_absolute_error: 0.1567 - val_mean_squared_error: 0.0540
# Epoch 8/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0296 - mean_absolute_error: 0.1294 - mean_squared_error: 0.0296 - val_loss: 0.0382 - val_mean_absolute_error: 0.1229 - val_mean_squared_error: 0.0382
# Epoch 9/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0238 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0238 - val_loss: 0.0393 - val_mean_absolute_error: 0.1318 - val_mean_squared_error: 0.0393
# Epoch 10/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_absolute_error: 0.1146 - mean_squared_error: 0.0230 - val_loss: 0.0358 - val_mean_absolute_error: 0.1098 - val_mean_squared_error: 0.0358
# Epoch 11/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0242 - mean_absolute_error: 0.1189 - mean_squared_error: 0.0242 - val_loss: 0.0374 - val_mean_absolute_error: 0.1164 - val_mean_squared_error: 0.0374
# Epoch 12/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0202 - mean_absolute_error: 0.1087 - mean_squared_error: 0.0202 - val_loss: 0.0397 - val_mean_absolute_error: 0.1417 - val_mean_squared_error: 0.0397
# Epoch 13/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0218 - mean_absolute_error: 0.1165 - mean_squared_error: 0.0218 - val_loss: 0.0340 - val_mean_absolute_error: 0.1089 - val_mean_squared_error: 0.0340
# Epoch 14/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0205 - mean_absolute_error: 0.1132 - mean_squared_error: 0.0205 - val_loss: 0.0337 - val_mean_absolute_error: 0.1106 - val_mean_squared_error: 0.0337
# Epoch 15/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0187 - mean_absolute_error: 0.1067 - mean_squared_error: 0.0187 - val_loss: 0.0399 - val_mean_absolute_error: 0.1248 - val_mean_squared_error: 0.0399
# Epoch 16/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0166 - mean_absolute_error: 0.1003 - mean_squared_error: 0.0166 - val_loss: 0.0348 - val_mean_absolute_error: 0.1233 - val_mean_squared_error: 0.0348
# Epoch 17/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0160 - mean_absolute_error: 0.0971 - mean_squared_error: 0.0160 - val_loss: 0.0356 - val_mean_absolute_error: 0.1139 - val_mean_squared_error: 0.0356
# Epoch 18/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0183 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0183 - val_loss: 0.0341 - val_mean_absolute_error: 0.1096 - val_mean_squared_error: 0.0341
# Epoch 19/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0157 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0157 - val_loss: 0.0436 - val_mean_absolute_error: 0.1339 - val_mean_squared_error: 0.0436
# Epoch 20/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0197 - mean_absolute_error: 0.1119 - mean_squared_error: 0.0197 - val_loss: 0.0337 - val_mean_absolute_error: 0.1126 - val_mean_squared_error: 0.0337
# Epoch 21/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0197 - mean_absolute_error: 0.1103 - mean_squared_error: 0.0197 - val_loss: 0.0341 - val_mean_absolute_error: 0.1212 - val_mean_squared_error: 0.0341
# Epoch 22/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0149 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0149 - val_loss: 0.0332 - val_mean_absolute_error: 0.1122 - val_mean_squared_error: 0.0332
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0138 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0138 - val_loss: 0.0349 - val_mean_absolute_error: 0.1233 - val_mean_squared_error: 0.0349
# Epoch 24/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0148 - mean_absolute_error: 0.0948 - mean_squared_error: 0.0148 - val_loss: 0.0362 - val_mean_absolute_error: 0.1187 - val_mean_squared_error: 0.0362
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0141 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0141 - val_loss: 0.0389 - val_mean_absolute_error: 0.1415 - val_mean_squared_error: 0.0389
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0146 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0146 - val_loss: 0.0356 - val_mean_absolute_error: 0.1166 - val_mean_squared_error: 0.0356
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0140 - mean_absolute_error: 0.0891 - mean_squared_error: 0.0140 - val_loss: 0.0339 - val_mean_absolute_error: 0.1199 - val_mean_squared_error: 0.0339
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0141 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0141 - val_loss: 0.0347 - val_mean_absolute_error: 0.1149 - val_mean_squared_error: 0.0347
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0128 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0128 - val_loss: 0.0346 - val_mean_absolute_error: 0.1286 - val_mean_squared_error: 0.0346
# Epoch 30/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0129 - mean_absolute_error: 0.0905 - mean_squared_error: 0.0129 - val_loss: 0.0337 - val_mean_absolute_error: 0.1214 - val_mean_squared_error: 0.0337
# Epoch 31/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0167 - mean_absolute_error: 0.1033 - mean_squared_error: 0.0167 - val_loss: 0.0395 - val_mean_absolute_error: 0.1280 - val_mean_squared_error: 0.0395
# Epoch 32/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0161 - val_loss: 0.0344 - val_mean_absolute_error: 0.1115 - val_mean_squared_error: 0.0344
# Epoch 33/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0156 - mean_absolute_error: 0.0975 - mean_squared_error: 0.0156 - val_loss: 0.0340 - val_mean_absolute_error: 0.1212 - val_mean_squared_error: 0.0340
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0124 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0124 - val_loss: 0.0445 - val_mean_absolute_error: 0.1373 - val_mean_squared_error: 0.0445
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0121 - mean_absolute_error: 0.0829 - mean_squared_error: 0.0121 - val_loss: 0.0353 - val_mean_absolute_error: 0.1174 - val_mean_squared_error: 0.0353
# Epoch 36/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0156 - mean_absolute_error: 0.0998 - mean_squared_error: 0.0156 - val_loss: 0.0345 - val_mean_absolute_error: 0.1170 - val_mean_squared_error: 0.0345
# Epoch 37/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0129 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0129 - val_loss: 0.0341 - val_mean_absolute_error: 0.1119 - val_mean_squared_error: 0.0341
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0116 - mean_absolute_error: 0.0835 - mean_squared_error: 0.0116 - val_loss: 0.0418 - val_mean_absolute_error: 0.1524 - val_mean_squared_error: 0.0418
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0125 - mean_absolute_error: 0.0852 - mean_squared_error: 0.0125 - val_loss: 0.0431 - val_mean_absolute_error: 0.1567 - val_mean_squared_error: 0.0431
# Epoch 40/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0135 - mean_absolute_error: 0.0905 - mean_squared_error: 0.0135 - val_loss: 0.0351 - val_mean_absolute_error: 0.1295 - val_mean_squared_error: 0.0351
# Epoch 41/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0858 - mean_squared_error: 0.0119 - val_loss: 0.0331 - val_mean_absolute_error: 0.1161 - val_mean_squared_error: 0.0331
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0109 - mean_absolute_error: 0.0792 - mean_squared_error: 0.0109 - val_loss: 0.0352 - val_mean_absolute_error: 0.1266 - val_mean_squared_error: 0.0352
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0110 - mean_absolute_error: 0.0823 - mean_squared_error: 0.0110 - val_loss: 0.0370 - val_mean_absolute_error: 0.1263 - val_mean_squared_error: 0.0370
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.0790 - mean_squared_error: 0.0105 - val_loss: 0.0337 - val_mean_absolute_error: 0.1192 - val_mean_squared_error: 0.0337
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0104 - mean_absolute_error: 0.0798 - mean_squared_error: 0.0104 - val_loss: 0.0354 - val_mean_absolute_error: 0.1229 - val_mean_squared_error: 0.0354
# Epoch 46/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.0851 - mean_squared_error: 0.0117 - val_loss: 0.0345 - val_mean_absolute_error: 0.1298 - val_mean_squared_error: 0.0345
# Epoch 47/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0821 - mean_squared_error: 0.0113 - val_loss: 0.0308 - val_mean_absolute_error: 0.1137 - val_mean_squared_error: 0.0308
# Epoch 48/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0096 - mean_absolute_error: 0.0734 - mean_squared_error: 0.0096 - val_loss: 0.0342 - val_mean_absolute_error: 0.1092 - val_mean_squared_error: 0.0342
# Epoch 49/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0765 - mean_squared_error: 0.0095 - val_loss: 0.0301 - val_mean_absolute_error: 0.1132 - val_mean_squared_error: 0.0301
# Epoch 50/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0103 - mean_absolute_error: 0.0792 - mean_squared_error: 0.0103 - val_loss: 0.0529 - val_mean_absolute_error: 0.1828 - val_mean_squared_error: 0.0529
# Epoch 51/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0124 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0124 - val_loss: 0.0444 - val_mean_absolute_error: 0.1346 - val_mean_squared_error: 0.0444
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0114 - mean_absolute_error: 0.0822 - mean_squared_error: 0.0114 - val_loss: 0.0369 - val_mean_absolute_error: 0.1393 - val_mean_squared_error: 0.0369
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0131 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0131 - val_loss: 0.0325 - val_mean_absolute_error: 0.1145 - val_mean_squared_error: 0.0325
# Epoch 54/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0793 - mean_squared_error: 0.0102 - val_loss: 0.0314 - val_mean_absolute_error: 0.1195 - val_mean_squared_error: 0.0314
# Epoch 55/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0096 - mean_absolute_error: 0.0760 - mean_squared_error: 0.0096 - val_loss: 0.0330 - val_mean_absolute_error: 0.1169 - val_mean_squared_error: 0.0330
# Epoch 56/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0122 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0122 - val_loss: 0.0356 - val_mean_absolute_error: 0.1151 - val_mean_squared_error: 0.0356
# Epoch 57/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0093 - mean_absolute_error: 0.0726 - mean_squared_error: 0.0093 - val_loss: 0.0337 - val_mean_absolute_error: 0.1235 - val_mean_squared_error: 0.0337
# Epoch 58/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0777 - mean_squared_error: 0.0100 - val_loss: 0.0372 - val_mean_absolute_error: 0.1267 - val_mean_squared_error: 0.0372
# Epoch 59/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0688 - mean_squared_error: 0.0084 - val_loss: 0.0314 - val_mean_absolute_error: 0.1228 - val_mean_squared_error: 0.0314
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0104 - mean_absolute_error: 0.0787 - mean_squared_error: 0.0104 - val_loss: 0.0326 - val_mean_absolute_error: 0.1188 - val_mean_squared_error: 0.0326
# Epoch 61/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0703 - mean_squared_error: 0.0084 - val_loss: 0.0358 - val_mean_absolute_error: 0.1328 - val_mean_squared_error: 0.0358
# Epoch 62/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0132 - val_loss: 0.0344 - val_mean_absolute_error: 0.1324 - val_mean_squared_error: 0.0344
# Epoch 63/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0106 - mean_absolute_error: 0.0807 - mean_squared_error: 0.0106 - val_loss: 0.0407 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0407
# Epoch 64/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0783 - mean_squared_error: 0.0095 - val_loss: 0.0389 - val_mean_absolute_error: 0.1283 - val_mean_squared_error: 0.0389
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0736 - mean_squared_error: 0.0088 - val_loss: 0.0374 - val_mean_absolute_error: 0.1384 - val_mean_squared_error: 0.0374
# Epoch 66/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0099 - mean_absolute_error: 0.0768 - mean_squared_error: 0.0099 - val_loss: 0.0396 - val_mean_absolute_error: 0.1245 - val_mean_squared_error: 0.0396
# Epoch 67/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0091 - mean_absolute_error: 0.0685 - mean_squared_error: 0.0091 - val_loss: 0.0355 - val_mean_absolute_error: 0.1248 - val_mean_squared_error: 0.0355
# Epoch 68/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0860 - mean_squared_error: 0.0121 - val_loss: 0.0351 - val_mean_absolute_error: 0.1224 - val_mean_squared_error: 0.0351
# Epoch 69/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.0721 - mean_squared_error: 0.0089 - val_loss: 0.0326 - val_mean_absolute_error: 0.1153 - val_mean_squared_error: 0.0326
# Epoch 70/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0666 - mean_squared_error: 0.0077 - val_loss: 0.0321 - val_mean_absolute_error: 0.1230 - val_mean_squared_error: 0.0321
# Epoch 71/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0664 - mean_squared_error: 0.0080 - val_loss: 0.0355 - val_mean_absolute_error: 0.1345 - val_mean_squared_error: 0.0355
# Epoch 72/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0103 - mean_absolute_error: 0.0804 - mean_squared_error: 0.0103 - val_loss: 0.0341 - val_mean_absolute_error: 0.1250 - val_mean_squared_error: 0.0341
# Epoch 73/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0710 - mean_squared_error: 0.0088 - val_loss: 0.0407 - val_mean_absolute_error: 0.1494 - val_mean_squared_error: 0.0407
# Epoch 74/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0782 - mean_squared_error: 0.0097 - val_loss: 0.0378 - val_mean_absolute_error: 0.1289 - val_mean_squared_error: 0.0378
# Epoch 75/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0087 - mean_absolute_error: 0.0724 - mean_squared_error: 0.0087 - val_loss: 0.0381 - val_mean_absolute_error: 0.1228 - val_mean_squared_error: 0.0381
# Epoch 76/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0743 - mean_squared_error: 0.0092 - val_loss: 0.0328 - val_mean_absolute_error: 0.1216 - val_mean_squared_error: 0.0328
# Epoch 77/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0625 - mean_squared_error: 0.0069 - val_loss: 0.0357 - val_mean_absolute_error: 0.1239 - val_mean_squared_error: 0.0357
# Epoch 78/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_absolute_error: 0.0670 - mean_squared_error: 0.0075 - val_loss: 0.0326 - val_mean_absolute_error: 0.1150 - val_mean_squared_error: 0.0326
# Epoch 79/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0673 - mean_squared_error: 0.0077 - val_loss: 0.0356 - val_mean_absolute_error: 0.1199 - val_mean_squared_error: 0.0356
# Epoch 80/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0619 - mean_squared_error: 0.0068 - val_loss: 0.0362 - val_mean_absolute_error: 0.1273 - val_mean_squared_error: 0.0362
# Epoch 81/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0087 - mean_absolute_error: 0.0737 - mean_squared_error: 0.0087 - val_loss: 0.0505 - val_mean_absolute_error: 0.1577 - val_mean_squared_error: 0.0505
# Epoch 82/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0123 - val_loss: 0.0273 - val_mean_absolute_error: 0.1121 - val_mean_squared_error: 0.0273
# Epoch 83/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0763 - mean_squared_error: 0.0095 - val_loss: 0.0430 - val_mean_absolute_error: 0.1341 - val_mean_squared_error: 0.0430
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0101 - mean_absolute_error: 0.0760 - mean_squared_error: 0.0101 - val_loss: 0.0317 - val_mean_absolute_error: 0.1230 - val_mean_squared_error: 0.0317
# Epoch 85/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0705 - mean_squared_error: 0.0085 - val_loss: 0.0447 - val_mean_absolute_error: 0.1346 - val_mean_squared_error: 0.0447
# Epoch 86/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.0817 - mean_squared_error: 0.0112 - val_loss: 0.0293 - val_mean_absolute_error: 0.1153 - val_mean_squared_error: 0.0293
# Epoch 87/100
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_absolute_error: 0.0707 - mean_squared_error: 0.0084 - val_loss: 0.0360 - val_mean_absolute_error: 0.1211 - val_mean_squared_error: 0.0360
# Epoch 88/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_absolute_error: 0.0684 - mean_squared_error: 0.0075 - val_loss: 0.0366 - val_mean_absolute_error: 0.1201 - val_mean_squared_error: 0.0366
# Epoch 89/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0075 - val_loss: 0.0412 - val_mean_absolute_error: 0.1555 - val_mean_squared_error: 0.0412
# Epoch 90/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0108 - mean_absolute_error: 0.0793 - mean_squared_error: 0.0108 - val_loss: 0.0336 - val_mean_absolute_error: 0.1197 - val_mean_squared_error: 0.0336
# Epoch 91/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0677 - mean_squared_error: 0.0085 - val_loss: 0.0372 - val_mean_absolute_error: 0.1255 - val_mean_squared_error: 0.0372
# Epoch 92/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0689 - mean_squared_error: 0.0081 - val_loss: 0.0399 - val_mean_absolute_error: 0.1551 - val_mean_squared_error: 0.0399
# Epoch 93/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0709 - mean_squared_error: 0.0082 - val_loss: 0.0367 - val_mean_absolute_error: 0.1298 - val_mean_squared_error: 0.0367
# Epoch 94/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0698 - mean_squared_error: 0.0079 - val_loss: 0.0360 - val_mean_absolute_error: 0.1215 - val_mean_squared_error: 0.0360
# Epoch 95/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0062 - mean_absolute_error: 0.0601 - mean_squared_error: 0.0062 - val_loss: 0.0335 - val_mean_absolute_error: 0.1158 - val_mean_squared_error: 0.0335
# Epoch 96/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0689 - mean_squared_error: 0.0080 - val_loss: 0.0356 - val_mean_absolute_error: 0.1201 - val_mean_squared_error: 0.0356
# Epoch 97/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0634 - mean_squared_error: 0.0070 - val_loss: 0.0324 - val_mean_absolute_error: 0.1147 - val_mean_squared_error: 0.0324
# Epoch 98/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0631 - mean_squared_error: 0.0068 - val_loss: 0.0330 - val_mean_absolute_error: 0.1156 - val_mean_squared_error: 0.0330
# Epoch 99/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0573 - mean_squared_error: 0.0057 - val_loss: 0.0358 - val_mean_absolute_error: 0.1184 - val_mean_squared_error: 0.0358
# Epoch 100/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0702 - mean_squared_error: 0.0082 - val_loss: 0.0382 - val_mean_absolute_error: 0.1424 - val_mean_squared_error: 0.0382

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.xlabel("Epochs")
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.show()

# %%
test_predictions=model.predict(X_test)
model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0382 - mean_absolute_error: 0.1424 - mean_squared_error: 0.0382
# [0.03815935552120209, 0.14241354167461395, 0.03815935552120209]

# %% [markdown]
# ### Algorithm no. 04 - Polynomial Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M2, target, test_size=0.2, random_state=0)
deg=2 # Degree 9 is giving the error of insufficient memory
X_train_poly2=PolynomialFeatures(degree=deg).fit_transform(X_train)
X_train_poly2=pd.DataFrame(X_train_poly2)
X_train_poly2=X_train_poly2.drop([0],axis=1)
model5=LinearRegression()
model5.fit(X_train_poly2,y_train)

print('Training data r-square:', model5.score(X_train_poly2, y_train))
X_test_poly2=PolynomialFeatures(degree=deg).fit_transform(X_test)
X_test_poly2=pd.DataFrame(X_test_poly2)
X_test_poly2=X_test_poly2.drop([0],axis=1)
print('Test data r-square:', model5.score(X_test_poly2, y_test))
# print('Number of non-zero features:',np.sum(model5.coef_ != 0))
# Out:
# Training data r-square: 0.9856203584476514
# Test data r-square: 0.6987373033798234

# %% [markdown]
# # Model 3

# %%
Predictor_M3=Predictors.iloc[0:571,0:34]#Slicing
Predictor_M3=Predictor_M3.drop("MT-442", axis=1)
Predictor_M3.head(3)# Only 1st, 2nd & 3rd year Grades.
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
#
#    ME-107  ...  EF-303  HS-304  CS-301  CS-302  TC-383  EL-332  CS-318  \
# 0     1.7  ...     1.7     2.4     3.0     2.0     2.4     2.0     1.7
# 1     1.0  ...     1.0     1.7     3.7     1.4     1.7     2.0     3.7
# 2     3.7  ...     2.4     4.0     3.4     3.7     3.0     3.4     3.7
#
#    CS-306  CS-312  CS-317
# 0     2.0     1.7     1.7
# 1     1.0     1.4     1.0
# 2     3.7     3.0     3.0
#
# [3 rows x 33 columns]

# %% [markdown]
# ### Algorithm no. 01 - Linear Regression

# %%
X_train_M3_lr,X_test_M3_lr,Y_train_M3_lr,Y_test_M3_lr = train_test_split(Predictor_M3, target,test_size=0.2,random_state=5) # Implementing 80 and 20 split
r3=LinearRegression()
r3.fit(X_train_M3_lr,Y_train_M3_lr)
print("The training accuracy", r3.score(X_train_M3_lr,Y_train_M3_lr))
print("The testing accuracy",r3.score(X_test_M3_lr,Y_test_M3_lr))
# Out:
# The training accuracy 0.9380411174884866
# The testing accuracy 0.9321933295381652

# %% [markdown]
# ### Algorithm no. 02 - Regression Tree

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M3, target, test_size=0.3)
rt = DecisionTreeRegressor(criterion = 'mse', max_depth=5)
model_r = rt.fit(X_train, y_train)
y_test_pred = model_r.predict(X_test)
y_train_pred = model_r.predict(X_train)

print('R Squared Score (train) is:', r2_score(y_train, y_train_pred))
print('R Squared Score (test) is:', r2_score(y_test, y_test_pred))
# Out:
# R Squared Score (train) is: 0.9259952798938472
# R Squared Score (test) is: 0.7920806682792593
# E:\Programs\Python310\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# ### Algorithm no. 03 - ANN

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M3, target, test_size=0.2)
model=models.Sequential()
model.add(layers.Dense(64,activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(1,activation='linear'))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['mean_absolute_error','mean_squared_error'])
history = model.fit(X_train,y_train,epochs=100, batch_size=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4347 - mean_absolute_error: 0.4213 - mean_squared_error: 0.4347 - val_loss: 0.0324 - val_mean_absolute_error: 0.1366 - val_mean_squared_error: 0.0324
# Epoch 2/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0554 - mean_absolute_error: 0.1460 - mean_squared_error: 0.0554 - val_loss: 0.0342 - val_mean_absolute_error: 0.1395 - val_mean_squared_error: 0.0342
# Epoch 3/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0426 - mean_absolute_error: 0.1293 - mean_squared_error: 0.0426 - val_loss: 0.0273 - val_mean_absolute_error: 0.1268 - val_mean_squared_error: 0.0273
# Epoch 4/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_absolute_error: 0.1218 - mean_squared_error: 0.0362 - val_loss: 0.0212 - val_mean_absolute_error: 0.1055 - val_mean_squared_error: 0.0212
# Epoch 5/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0359 - mean_absolute_error: 0.1280 - mean_squared_error: 0.0359 - val_loss: 0.0321 - val_mean_absolute_error: 0.1402 - val_mean_squared_error: 0.0321
# Epoch 6/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0322 - mean_absolute_error: 0.1084 - mean_squared_error: 0.0322 - val_loss: 0.0241 - val_mean_absolute_error: 0.1207 - val_mean_squared_error: 0.0241
# Epoch 7/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0273 - mean_absolute_error: 0.1016 - mean_squared_error: 0.0273 - val_loss: 0.0181 - val_mean_absolute_error: 0.0943 - val_mean_squared_error: 0.0181
# Epoch 8/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0226 - mean_absolute_error: 0.0871 - mean_squared_error: 0.0226 - val_loss: 0.0178 - val_mean_absolute_error: 0.0980 - val_mean_squared_error: 0.0178
# Epoch 9/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0262 - mean_absolute_error: 0.1028 - mean_squared_error: 0.0262 - val_loss: 0.0155 - val_mean_absolute_error: 0.0875 - val_mean_squared_error: 0.0155
# Epoch 10/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0217 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0217 - val_loss: 0.0157 - val_mean_absolute_error: 0.0788 - val_mean_squared_error: 0.0157
# Epoch 11/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0226 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0226 - val_loss: 0.0173 - val_mean_absolute_error: 0.0906 - val_mean_squared_error: 0.0173
# Epoch 12/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0198 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0198 - val_loss: 0.0167 - val_mean_absolute_error: 0.0782 - val_mean_squared_error: 0.0167
# Epoch 13/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0180 - mean_absolute_error: 0.0838 - mean_squared_error: 0.0180 - val_loss: 0.0175 - val_mean_absolute_error: 0.0803 - val_mean_squared_error: 0.0175
# Epoch 14/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0171 - mean_absolute_error: 0.0820 - mean_squared_error: 0.0171 - val_loss: 0.0180 - val_mean_absolute_error: 0.0854 - val_mean_squared_error: 0.0180
# Epoch 15/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0132 - mean_absolute_error: 0.0690 - mean_squared_error: 0.0132 - val_loss: 0.0188 - val_mean_absolute_error: 0.0878 - val_mean_squared_error: 0.0188
# Epoch 16/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0152 - mean_absolute_error: 0.0798 - mean_squared_error: 0.0152 - val_loss: 0.0168 - val_mean_absolute_error: 0.0773 - val_mean_squared_error: 0.0168
# Epoch 17/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0141 - mean_absolute_error: 0.0769 - mean_squared_error: 0.0141 - val_loss: 0.0353 - val_mean_absolute_error: 0.1193 - val_mean_squared_error: 0.0353
# Epoch 18/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0150 - mean_absolute_error: 0.0806 - mean_squared_error: 0.0150 - val_loss: 0.0172 - val_mean_absolute_error: 0.0778 - val_mean_squared_error: 0.0172
# Epoch 19/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0143 - mean_absolute_error: 0.0775 - mean_squared_error: 0.0143 - val_loss: 0.0159 - val_mean_absolute_error: 0.0753 - val_mean_squared_error: 0.0159
# Epoch 20/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0745 - mean_squared_error: 0.0107 - val_loss: 0.0297 - val_mean_absolute_error: 0.1297 - val_mean_squared_error: 0.0297
# Epoch 21/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0812 - mean_squared_error: 0.0132 - val_loss: 0.0333 - val_mean_absolute_error: 0.1399 - val_mean_squared_error: 0.0333
# Epoch 22/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0101 - mean_absolute_error: 0.0692 - mean_squared_error: 0.0101 - val_loss: 0.0205 - val_mean_absolute_error: 0.0742 - val_mean_squared_error: 0.0205
# Epoch 23/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0616 - mean_squared_error: 0.0071 - val_loss: 0.0177 - val_mean_absolute_error: 0.0734 - val_mean_squared_error: 0.0177
# Epoch 24/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0060 - mean_absolute_error: 0.0592 - mean_squared_error: 0.0060 - val_loss: 0.0187 - val_mean_absolute_error: 0.0727 - val_mean_squared_error: 0.0187
# Epoch 25/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0515 - mean_squared_error: 0.0051 - val_loss: 0.0179 - val_mean_absolute_error: 0.0723 - val_mean_squared_error: 0.0179
# Epoch 26/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0053 - mean_absolute_error: 0.0526 - mean_squared_error: 0.0053 - val_loss: 0.0199 - val_mean_absolute_error: 0.0776 - val_mean_squared_error: 0.0199
# Epoch 27/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0057 - mean_absolute_error: 0.0584 - mean_squared_error: 0.0057 - val_loss: 0.0179 - val_mean_absolute_error: 0.0820 - val_mean_squared_error: 0.0179
# Epoch 28/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0552 - mean_squared_error: 0.0050 - val_loss: 0.0311 - val_mean_absolute_error: 0.1134 - val_mean_squared_error: 0.0311
# Epoch 29/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0063 - mean_absolute_error: 0.0613 - mean_squared_error: 0.0063 - val_loss: 0.0209 - val_mean_absolute_error: 0.0796 - val_mean_squared_error: 0.0209
# Epoch 30/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0041 - val_loss: 0.0200 - val_mean_absolute_error: 0.0709 - val_mean_squared_error: 0.0200
# Epoch 31/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0059 - mean_absolute_error: 0.0516 - mean_squared_error: 0.0059 - val_loss: 0.0199 - val_mean_absolute_error: 0.0823 - val_mean_squared_error: 0.0199
# Epoch 32/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0053 - mean_absolute_error: 0.0562 - mean_squared_error: 0.0053 - val_loss: 0.0201 - val_mean_absolute_error: 0.0701 - val_mean_squared_error: 0.0201
# Epoch 33/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0038 - val_loss: 0.0230 - val_mean_absolute_error: 0.0774 - val_mean_squared_error: 0.0230
# Epoch 34/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0030 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0030 - val_loss: 0.0180 - val_mean_absolute_error: 0.0673 - val_mean_squared_error: 0.0180
# Epoch 35/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0034 - val_loss: 0.0180 - val_mean_absolute_error: 0.0684 - val_mean_squared_error: 0.0180
# Epoch 36/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0037 - val_loss: 0.0187 - val_mean_absolute_error: 0.0675 - val_mean_squared_error: 0.0187
# Epoch 37/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0032 - val_loss: 0.0194 - val_mean_absolute_error: 0.0726 - val_mean_squared_error: 0.0194
# Epoch 38/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0040 - val_loss: 0.0161 - val_mean_absolute_error: 0.0687 - val_mean_squared_error: 0.0161
# Epoch 39/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0044 - val_loss: 0.0224 - val_mean_absolute_error: 0.0744 - val_mean_squared_error: 0.0224
# Epoch 40/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0516 - mean_squared_error: 0.0067 - val_loss: 0.0324 - val_mean_absolute_error: 0.1141 - val_mean_squared_error: 0.0324
# Epoch 41/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.0609 - mean_squared_error: 0.0089 - val_loss: 0.0159 - val_mean_absolute_error: 0.0909 - val_mean_squared_error: 0.0159
# Epoch 42/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0566 - mean_squared_error: 0.0076 - val_loss: 0.0191 - val_mean_absolute_error: 0.0676 - val_mean_squared_error: 0.0191
# Epoch 43/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0031 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0031 - val_loss: 0.0176 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0176
# Epoch 44/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0029 - val_loss: 0.0225 - val_mean_absolute_error: 0.0880 - val_mean_squared_error: 0.0225
# Epoch 45/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0030 - val_loss: 0.0188 - val_mean_absolute_error: 0.0657 - val_mean_squared_error: 0.0188
# Epoch 46/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0030 - val_loss: 0.0198 - val_mean_absolute_error: 0.0722 - val_mean_squared_error: 0.0198
# Epoch 47/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0026 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0026 - val_loss: 0.0195 - val_mean_absolute_error: 0.0757 - val_mean_squared_error: 0.0195
# Epoch 48/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0385 - mean_squared_error: 0.0026 - val_loss: 0.0200 - val_mean_absolute_error: 0.0673 - val_mean_squared_error: 0.0200
# Epoch 49/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0385 - mean_squared_error: 0.0024 - val_loss: 0.0193 - val_mean_absolute_error: 0.0770 - val_mean_squared_error: 0.0193
# Epoch 50/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0026 - mean_absolute_error: 0.0396 - mean_squared_error: 0.0026 - val_loss: 0.0189 - val_mean_absolute_error: 0.0777 - val_mean_squared_error: 0.0189
# Epoch 51/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0368 - mean_squared_error: 0.0023 - val_loss: 0.0209 - val_mean_absolute_error: 0.0759 - val_mean_squared_error: 0.0209
# Epoch 52/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0031 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0031 - val_loss: 0.0211 - val_mean_absolute_error: 0.0700 - val_mean_squared_error: 0.0211
# Epoch 53/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0370 - mean_squared_error: 0.0024 - val_loss: 0.0177 - val_mean_absolute_error: 0.0664 - val_mean_squared_error: 0.0177
# Epoch 54/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0022 - mean_absolute_error: 0.0360 - mean_squared_error: 0.0022 - val_loss: 0.0182 - val_mean_absolute_error: 0.0675 - val_mean_squared_error: 0.0182
# Epoch 55/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0386 - mean_squared_error: 0.0023 - val_loss: 0.0189 - val_mean_absolute_error: 0.0756 - val_mean_squared_error: 0.0189
# Epoch 56/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0042 - mean_absolute_error: 0.0505 - mean_squared_error: 0.0042 - val_loss: 0.0168 - val_mean_absolute_error: 0.0757 - val_mean_squared_error: 0.0168
# Epoch 57/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0035 - val_loss: 0.0209 - val_mean_absolute_error: 0.0720 - val_mean_squared_error: 0.0209
# Epoch 58/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0040 - val_loss: 0.0198 - val_mean_absolute_error: 0.0763 - val_mean_squared_error: 0.0198
# Epoch 59/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0637 - mean_squared_error: 0.0086 - val_loss: 0.0150 - val_mean_absolute_error: 0.0692 - val_mean_squared_error: 0.0150
# Epoch 60/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0570 - mean_squared_error: 0.0052 - val_loss: 0.0225 - val_mean_absolute_error: 0.0838 - val_mean_squared_error: 0.0225
# Epoch 61/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0664 - mean_squared_error: 0.0066 - val_loss: 0.0260 - val_mean_absolute_error: 0.1038 - val_mean_squared_error: 0.0260
# Epoch 62/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0541 - mean_squared_error: 0.0051 - val_loss: 0.0208 - val_mean_absolute_error: 0.0790 - val_mean_squared_error: 0.0208
# Epoch 63/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0056 - val_loss: 0.0287 - val_mean_absolute_error: 0.0989 - val_mean_squared_error: 0.0287
# Epoch 64/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0467 - mean_squared_error: 0.0040 - val_loss: 0.0177 - val_mean_absolute_error: 0.0628 - val_mean_squared_error: 0.0177
# Epoch 65/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0042 - val_loss: 0.0222 - val_mean_absolute_error: 0.0676 - val_mean_squared_error: 0.0222
# Epoch 66/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0032 - val_loss: 0.0188 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0188
# Epoch 67/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0398 - mean_squared_error: 0.0025 - val_loss: 0.0191 - val_mean_absolute_error: 0.0652 - val_mean_squared_error: 0.0191
# Epoch 68/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0027 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0027 - val_loss: 0.0215 - val_mean_absolute_error: 0.0762 - val_mean_squared_error: 0.0215
# Epoch 69/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0385 - mean_squared_error: 0.0023 - val_loss: 0.0264 - val_mean_absolute_error: 0.0886 - val_mean_squared_error: 0.0264
# Epoch 70/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0033 - val_loss: 0.0205 - val_mean_absolute_error: 0.0666 - val_mean_squared_error: 0.0205
# Epoch 71/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0034 - val_loss: 0.0213 - val_mean_absolute_error: 0.0691 - val_mean_squared_error: 0.0213
# Epoch 72/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0033 - val_loss: 0.0202 - val_mean_absolute_error: 0.0695 - val_mean_squared_error: 0.0202
# Epoch 73/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0347 - mean_squared_error: 0.0019 - val_loss: 0.0198 - val_mean_absolute_error: 0.0711 - val_mean_squared_error: 0.0198
# Epoch 74/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0343 - mean_squared_error: 0.0020 - val_loss: 0.0200 - val_mean_absolute_error: 0.0679 - val_mean_squared_error: 0.0200
# Epoch 75/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0326 - mean_squared_error: 0.0017 - val_loss: 0.0211 - val_mean_absolute_error: 0.0768 - val_mean_squared_error: 0.0211
# Epoch 76/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0383 - mean_squared_error: 0.0023 - val_loss: 0.0185 - val_mean_absolute_error: 0.0657 - val_mean_squared_error: 0.0185
# Epoch 77/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0021 - mean_absolute_error: 0.0362 - mean_squared_error: 0.0021 - val_loss: 0.0271 - val_mean_absolute_error: 0.1090 - val_mean_squared_error: 0.0271
# Epoch 78/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0364 - mean_squared_error: 0.0023 - val_loss: 0.0208 - val_mean_absolute_error: 0.0685 - val_mean_squared_error: 0.0208
# Epoch 79/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0330 - mean_squared_error: 0.0018 - val_loss: 0.0204 - val_mean_absolute_error: 0.0670 - val_mean_squared_error: 0.0204
# Epoch 80/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0377 - mean_squared_error: 0.0022 - val_loss: 0.0191 - val_mean_absolute_error: 0.0691 - val_mean_squared_error: 0.0191
# Epoch 81/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0338 - mean_squared_error: 0.0019 - val_loss: 0.0222 - val_mean_absolute_error: 0.0768 - val_mean_squared_error: 0.0222
# Epoch 82/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0354 - mean_squared_error: 0.0020 - val_loss: 0.0174 - val_mean_absolute_error: 0.0680 - val_mean_squared_error: 0.0174
# Epoch 83/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0374 - mean_squared_error: 0.0024 - val_loss: 0.0224 - val_mean_absolute_error: 0.0901 - val_mean_squared_error: 0.0224
# Epoch 84/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0028 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0028 - val_loss: 0.0202 - val_mean_absolute_error: 0.0767 - val_mean_squared_error: 0.0202
# Epoch 85/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0336 - mean_squared_error: 0.0018 - val_loss: 0.0235 - val_mean_absolute_error: 0.0727 - val_mean_squared_error: 0.0235
# Epoch 86/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0018 - val_loss: 0.0240 - val_mean_absolute_error: 0.0759 - val_mean_squared_error: 0.0240
# Epoch 87/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0391 - mean_squared_error: 0.0029 - val_loss: 0.0235 - val_mean_absolute_error: 0.0803 - val_mean_squared_error: 0.0235
# Epoch 88/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0037 - val_loss: 0.0234 - val_mean_absolute_error: 0.0701 - val_mean_squared_error: 0.0234
# Epoch 89/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0042 - val_loss: 0.0137 - val_mean_absolute_error: 0.0669 - val_mean_squared_error: 0.0137
# Epoch 90/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0126 - mean_absolute_error: 0.0735 - mean_squared_error: 0.0126 - val_loss: 0.0395 - val_mean_absolute_error: 0.1568 - val_mean_squared_error: 0.0395
# Epoch 91/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0100 - mean_absolute_error: 0.0710 - mean_squared_error: 0.0100 - val_loss: 0.0182 - val_mean_absolute_error: 0.0730 - val_mean_squared_error: 0.0182
# Epoch 92/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0500 - mean_squared_error: 0.0051 - val_loss: 0.0223 - val_mean_absolute_error: 0.0854 - val_mean_squared_error: 0.0223
# Epoch 93/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0082 - val_loss: 0.0186 - val_mean_absolute_error: 0.0731 - val_mean_squared_error: 0.0186
# Epoch 94/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0570 - mean_squared_error: 0.0055 - val_loss: 0.0168 - val_mean_absolute_error: 0.0873 - val_mean_squared_error: 0.0168
# Epoch 95/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0036 - val_loss: 0.0182 - val_mean_absolute_error: 0.0697 - val_mean_squared_error: 0.0182
# Epoch 96/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0381 - mean_squared_error: 0.0024 - val_loss: 0.0142 - val_mean_absolute_error: 0.0681 - val_mean_squared_error: 0.0142
# Epoch 97/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0354 - mean_squared_error: 0.0020 - val_loss: 0.0185 - val_mean_absolute_error: 0.0734 - val_mean_squared_error: 0.0185
# Epoch 98/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0027 - val_loss: 0.0159 - val_mean_absolute_error: 0.0632 - val_mean_squared_error: 0.0159
# Epoch 99/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0391 - mean_squared_error: 0.0028 - val_loss: 0.0163 - val_mean_absolute_error: 0.0651 - val_mean_squared_error: 0.0163
# Epoch 100/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0036 - val_loss: 0.0180 - val_mean_absolute_error: 0.0691 - val_mean_squared_error: 0.0180

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.xlabel("Epochs")
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.show()

# %%
test_predictions=model.predict(X_test)
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0180 - mean_absolute_error: 0.0691 - mean_squared_error: 0.0180
# [0.018011324107646942, 0.06912943720817566, 0.018011324107646942]

# %% [markdown]
# ### Algorithm no. 04 - Polynomial Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M3, target, test_size=0.2, random_state=10)
deg=3 # Degree 9 is giving the error of insufficient memory
X_train_poly2=PolynomialFeatures(degree=deg).fit_transform(X_train)
X_train_poly2=pd.DataFrame(X_train_poly2)
X_train_poly2=X_train_poly2.drop([0],axis=1)
model5=LinearRegression()
model5.fit(X_train_poly2,y_train)

print('Training data r-square:', model5.score(X_train_poly2, y_train))
X_test_poly2=PolynomialFeatures(degree=deg).fit_transform(X_test)
X_test_poly2=pd.DataFrame(X_test_poly2)
X_test_poly2=X_test_poly2.drop([0],axis=1)
print('Test data r-square:', model5.score(X_test_poly2, y_test))
# print('Number of non-zero features:',np.sum(model5.coef_ != 0))
# Out:
# Training data r-square: 1.0
# Test data r-square: 0.9163396484232182

# %% [markdown]
# ##                                                     CGPA Prediction System

# %%
#imports 
import warnings
warnings.filterwarnings('ignore')

import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
# Student information block
file = open("reportcard.jpg", "rb")
image = file.read()

image_headline = widgets.Image(
                    value=image,
                    format='jpg',
                    width='200',
                    height='300'
                )

label_headline = widgets.Label(
                    style={'description_width': 'initial'},
                    value='WELCOME TO CGPA PREDICTION MODEL'
                )

Space=widgets.Label(
                    style={'description_width': 'initial'},
                    value=''
                )

Student_Name=widgets.Text(
    placeholder='Enter Full Name',
    description='Name:',
    disabled=False
)

Seat_No=widgets.Text(
    placeholder='Enter Seat No',
    description='Seat No:',
    disabled=False
)

Student_Year=widgets.Dropdown(
    options=['1st year', '1st & 2nd year', '1st, 2nd & 3rd year'],
    value=None,
    description='Year:',
    disabled=False,
)
vbox_headline = widgets.VBox([image_headline, Space, label_headline,Space, Student_Name,Seat_No,Student_Year])
display(vbox_headline)
# Out:
# VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\…

# %%
from ipywidgets import Button
enco_list=[('A+', 4.0), ('A', 4.0), ('A-',3.7), ('B+',3.4), ('B',3.0), ('B-',2.7), ('C+',2.4), ('C',2.0), ('C-',1.7),('D+',1.4), ('D',1.0), ('F',0.0), ('WU',0.0), ('W',0.0), ('I',0.0)]

print()
print("Please Click the 'Fill Grades' Button to fill your", Student_Year.value, "Grades")
button_send = widgets.Button(
                description='Fill Grades',
                tooltip='Send',
                style={'description_width': 'danger'}
            )

output = widgets.Output()

def on_button_clicked(event):
    with output:
            if Student_Year.value=='1st year':
                print("        **** First Year Courses ******     ")
                PH_121=widgets.Dropdown(
                options=enco_list,
                description='PH-121',
                )
                HS_101=widgets.Dropdown(
                    options=enco_list,
                    description='HS-101',
                )   
                CY_105=widgets.Dropdown(
                    options=enco_list,
                    description='CY-105',
                )   
                HS_105_12=widgets.Dropdown(
                    options=enco_list,
                    description='HS_105/12',
                )   
                MT_111=widgets.Dropdown(
                    options=enco_list,
                    description='MT-111',
                )   
                CS_105=widgets.Dropdown(
                options=enco_list,
                description='CS-105',
                )   
                CS_106=widgets.Dropdown(
                    options=enco_list,
                    description='CS-106',
                )
                EL_102=widgets.Dropdown(
                    options=enco_list,
                    description='EL-102',
                )   
                EE_119=widgets.Dropdown(
                    options=enco_list,
                    description='EE-119',
                )   
                ME_107=widgets.Dropdown(
                    options=enco_list,
                    description='ME-107',
                )
                CS_107=widgets.Dropdown(
                    options=enco_list,
                    description='CS-107',
                )
                vboxM1_text = widgets.VBox([PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107, CS_107])
                display(vboxM1_text)

            elif Student_Year.value=='1st & 2nd year':
                print("        **** First Year Courses ******     ")
                PH_121=widgets.Dropdown(
                options=enco_list,
                description='PH-121',
                )
                HS_101=widgets.Dropdown(
                    options=enco_list,
                    description='HS-101',
                )   
                CY_105=widgets.Dropdown(
                    options=enco_list,
                    description='CY-105',
                )   
                HS_105_12=widgets.Dropdown(
                    options=enco_list,
                    description='HS_105/12',
                )   
                MT_111=widgets.Dropdown(
                    options=enco_list,
                    description='MT-111',
                )   
                CS_105=widgets.Dropdown(
                    options=enco_list,
                    description='CS-105',
                )   
                CS_106=widgets.Dropdown(
                    options=enco_list,
                    description='CS-106',
                )
                EL_102=widgets.Dropdown(
                    options=enco_list,
                    description='EL-102',
                )   
                EE_119=widgets.Dropdown(
                    options=enco_list,
                    description='EE-119',
                )   
                ME_107=widgets.Dropdown(
                    options=enco_list,
                    description='ME-107',
                )
                CS_107=widgets.Dropdown(
                    options=enco_list,
                    description='CS-107',
                )
                print("        **** Second Year Courses ******     ")
                HS_205_20=widgets.Dropdown(
                    options=enco_list,
                    description='HS-205/20',
                )
                MT_222=widgets.Dropdown(
                    options=enco_list,
                    description='MT-222',
                )
                EE_222=widgets.Dropdown(
                    options=enco_list,
                    description='EE-222',
                )
                MT_224=widgets.Dropdown(
                    options=enco_list,
                    description='MT-224',
                )
                CS_210=widgets.Dropdown(
                    options=enco_list,
                    description='CS-210',
                )
                CS_211=widgets.Dropdown(
                    options=enco_list,
                    description='CS-211',
                )
                CS_203=widgets.Dropdown(
                    options=enco_list,
                    description='CS-203',
                )
                CS_214=widgets.Dropdown(
                    options=enco_list,
                    description='CS-214',
                )
                EE_217=widgets.Dropdown(
                    options=enco_list,
                    description='EE-217',
                )
                CS_212=widgets.Dropdown(
                    options=enco_list,
                    description='CS-212',
                )
                CS_215=widgets.Dropdown(
                    options=enco_list,
                    description='CS-215',
                ) 
                vboxM2_text = widgets.VBox([PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107,CS_107, HS_205_20,MT_222,EE_222,MT_224,CS_210,CS_211,CS_203,CS_214,EE_217,CS_212,CS_215])
                display(vboxM2_text)

            if Student_Year.value=='1st, 2nd & 3rd year':
                print("        **** First Year Courses ******     ")
                PH_121=widgets.Dropdown(
                options=enco_list,
                description='PH-121',
                )
                HS_101=widgets.Dropdown(
                    options=enco_list,
                    description='HS-101',
                )   
                CY_105=widgets.Dropdown(
                    options=enco_list,
                    description='CY-105',
                )   
                HS_105_12=widgets.Dropdown(
                    options=enco_list,
                    description='HS_105/12',
                )   
                MT_111=widgets.Dropdown(
                    options=enco_list,
                    description='MT-111',
                )   
                CS_105=widgets.Dropdown(
                options=enco_list,
                description='CS-105',
                )   
                CS_106=widgets.Dropdown(
                    options=enco_list,
                    description='CS-106',
                )
                EL_102=widgets.Dropdown(
                    options=enco_list,
                    description='EL-102',
                )   
                EE_119=widgets.Dropdown(
                    options=enco_list,
                    description='EE-119',
                )   
                ME_107=widgets.Dropdown(
                    options=enco_list,
                    description='ME-107',
                )
                CS_107=widgets.Dropdown(
                    options=enco_list,
                    description='CS-107',
                )
                print("        **** Second Year Courses ******     ")
                HS_205_20=widgets.Dropdown(
                    options=enco_list,
                    description='HS-205/20',
                )
                MT_222=widgets.Dropdown(
                    options=enco_list,
                    description='MT-222',
                )
                EE_222=widgets.Dropdown(
                    options=enco_list,
                    description='EE-222',
                )
                MT_224=widgets.Dropdown(
                    options=enco_list,
                    description='MT-224',
                )
                CS_210=widgets.Dropdown(
                    options=enco_list,
                    description='CS-210',
                )
                CS_211=widgets.Dropdown(
                    options=enco_list,
                    description='CS-211',
                )
                CS_203=widgets.Dropdown(
                    options=enco_list,
                    description='CS-203',
                )
                CS_214=widgets.Dropdown(
                    options=enco_list,
                    description='CS-214',
                )
                EE_217=widgets.Dropdown(
                    options=enco_list,
                    description='EE-217',
                )
                CS_212=widgets.Dropdown(
                    options=enco_list,
                    description='CS-212',
                )
                CS_215=widgets.Dropdown(
                    options=enco_list,
                    description='CS-215',
                ) 
                print("        **** Third Year Courses ******     ")
                MT_331=widgets.Dropdown(
                    options=enco_list,
                    description='MT-331',
                ) 
                EF_303=widgets.Dropdown(
                    options=enco_list,
                    description='EF-303',
                ) 
                HS_304=widgets.Dropdown(
                    options=enco_list,
                    description='HS-304',
                ) 
                CS_301=widgets.Dropdown(
                    options=enco_list,
                    description='CS-301',
                ) 
                CS_302=widgets.Dropdown(
                    options=enco_list,
                    description='CS-302',
                ) 
                TC_383=widgets.Dropdown(
                    options=enco_list,
                    description='TC-383',
                )
                EL_332=widgets.Dropdown(
                    options=enco_list,
                    description='EL-332',
                )
                CS_318=widgets.Dropdown(
                    options=enco_list,
                    description='CS-318',
                )
                CS_306=widgets.Dropdown(
                    options=enco_list,
                    description='CS-306',
                )
                CS_312=widgets.Dropdown(
                    options=enco_list,
                    description='CS-312',
                )
                CS_317=widgets.Dropdown(
                    options=enco_list,
                    description='CS-317',
                )

                vboxM3_text = widgets.VBox([PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107,CS_107, HS_205_20,MT_222,EE_222,MT_224,CS_210,CS_211,CS_203,CS_214,EE_217,CS_212,CS_215,MT_331,EF_303,HS_304,CS_301,CS_302,TC_383,EL_332,CS_318,CS_306,CS_312,CS_317])
                display(vboxM3_text)
            
            print("Please Click the 'Submit Grades' Button to submit your Grades")
            button_send_G = widgets.Button(
                            description='Submit Grades',
                            tooltip='Send',
                            style={'description_width': 'initial'}
                        )

            output_G = widgets.Output()

            def on_button_clicked(event):
                with output_G:
                    clear_output()
                    grade_list1=[]
                    grade_list2=[]
                    grade_list3=[]
                    if Student_Year.value=='1st year':
                        for element in [PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107, CS_107]:
                            grade_list1.append(element.value)
                        print('Following is your GPAs of the grades submitted')
                        print(', '.join(map(str, grade_list1)))
                        print('\n')
                        print("Please Click the 'Predict CGPA' Button to display your CGPA")

                    if Student_Year.value=='1st & 2nd year':
                        for element in [PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107,CS_107, HS_205_20,MT_222,EE_222,MT_224,CS_210,CS_211,CS_203,CS_214,EE_217,CS_212,CS_215]:
                            grade_list2.append(element.value)
                        print('Following is your GPAs of the grades submitted')
                        print(', '.join(map(str, grade_list2)))
                        print('\n')
                        print("Please Click the 'Predict CGPA' Button to display your CGPA")

                    if Student_Year.value=='1st, 2nd & 3rd year':
                        for element in [PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107,CS_107, HS_205_20,MT_222,EE_222,MT_224,CS_210,CS_211,CS_203,CS_214,EE_217,CS_212,CS_215,MT_331,EF_303,HS_304,CS_301,CS_302,TC_383,EL_332,CS_318,CS_306,CS_312,CS_317]:
                            grade_list3.append(element.value)
                        print('Following is your GPAs of the grades submitted')
                        print(', '.join(map(str, grade_list3)))
                        print('\n')
                        print("Please Click the 'Predict CGPA' Button to display your CGPA")

                    button_send_P = widgets.Button(
                                    description='Predict CGPA',
                                    tooltip='Send',
                                    style={'description_width': 'initial'}
                                )
                    output_P = widgets.Output()

                    def on_button_clicked(event):
                        with output_P:
                            clear_output()
                            if Student_Year.value=='1st year':
                                lst1=[]
                                lst1.append(grade_list1)
                                df1 = pd.DataFrame (lst1, columns = ['PH-121', 'HS-101','CY-105','HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107', 'CS-107'])
                                y_pred1 = r1.predict(df1)
                                print("The Predicted CGPA of",Student_Name.value, ',',Seat_No.value,"on the basis of",Student_Year.value,"is"  ,round(y_pred1[0], 2))

                            if Student_Year.value=='1st & 2nd year':
                                lst2=[]
                                lst2.append(grade_list2)
                                df2 = pd.DataFrame (lst2, columns = ['PH-121', 'HS-101','CY-105','HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107','CS-107','HS-205/20','MT-222','EE-222','MT-224','CS-210','CS-211','CS-203','CS-214','EE-217','CS-212','CS-215'])
                                y_pred1 = r2.predict(df2)
#                                 print(y_pred1[0])
                                print("The Predicted CGPA of",Student_Name.value, ',',Seat_No.value,"on the basis of",Student_Year.value,"is"  ,round(y_pred1[0],2))

                            if Student_Year.value=='1st, 2nd & 3rd year':
                                lst3=[]
                                lst3.append(grade_list3)
                                df3 = pd.DataFrame (lst3, columns = ['PH-121', 'HS-101','CY-105','HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107','CS-107','HS-205/20','MT-222','EE-222','MT-224','CS-210','CS-211','CS-203','CS-214','EE-217','CS-212','CS-215','MT-331','EF-303','HS-304','CS-301','CS-302','TC-383','EL-332','CS-318','CS-306','CS-312','CS-317'])
                                y_pred1 = r3.predict(df3)
#                                 print(y_pred1[0])
                                print("The Predicted CGPA of",Student_Name.value, ',',Seat_No.value,"on the basis of",Student_Year.value,"is"  ,round(y_pred1[0],2))

########################### third button for confirming info ############################

                    button_send_P.on_click(on_button_clicked)

                    vbox_result_P = widgets.VBox([button_send_P, output_P])
                    display(vbox_result_P)
                    

########################### second button for confirming info ############################
            button_send_G.on_click(on_button_clicked)

            vbox_result_G = widgets.VBox([button_send_G, output_G])
            display(vbox_result_G)
            

########################### first button for confirming info ############################

button_send.on_click(on_button_clicked)

vbox_result = widgets.VBox([button_send,Space, output],padding=10, width='40%')
display(vbox_result)
# Out:
# Please Click the 'Fill Grades' Button to fill your None Grades
# VBox(children=(Button(description='Fill Grades', style=ButtonStyle(), tooltip='Send'), Label(value='', style=D…

# %%
import pickle


# import dill as pickle
#pickling
data = {"model1": r1,"model2": r2,"model3": r3}

with open('interface.pkl', 'wb') as file:
    pickle.dump(data, file)
with open('interface.pkl', 'rb') as file:
    data = pickle.load(file)
    
    
#loading model
# regressor_loaded = data["model1"]
# regressor_one = data["model1"]
# regressor_one.predict([[4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0]])


# regressor_three=data["model3"]
# regressor_three.predict([[4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 2.4, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 2.7, 4.0, 3.4, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0]])
