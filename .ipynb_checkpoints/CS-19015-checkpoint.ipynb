# %% [markdown]
# ### Group Members

# %% [raw]
# 1- Muneeza Baig CS-19015
# 2- Zuhaira Abdullah Siddiqui CS-19019
# 3- Syeda Ghazia Hashmi CS-19061

# %% [markdown]
# # Imports
# The relevant imports are called for the analysis

# %%
#all the imports are listed below. 
import numpy as np
import pandas as pd
from numpy import asarray
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from tensorflow.keras import models
from tensorflow.keras import layers

# %% [markdown]
# # Reading the dataset - Grades_Dataset.csv

# %%
# Reading the dataset.
data = pd.read_csv('The_Grades_Dataset.csv')

# Displaying the Head (Column Names) and '3' rows 
data.head(3)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
#
# [3 rows x 43 columns]

# %% [markdown]
# # Checking Unique Values

# %%
# Seeking the unique values present in the dataset
print(data['CS-318'].unique())
print(data['MT-222'].unique())
print(data['CS-406'].unique())
# Out:
# ['C-' 'A-' 'B+' 'B-' 'C' 'B' 'C+' 'D' 'D+' 'A' nan 'A+' 'WU' 'F' 'W']
# ['D' 'B-' 'A' 'D+' 'C' 'B+' 'A-' 'B' 'C+' nan 'C-' 'WU' 'F' 'A+' 'W']
# ['A-' 'A' 'B-' 'B' 'B+' nan 'C+' 'D' 'D+' 'C-' 'C' 'A+' 'F' 'W' 'WU']

# %% [raw]
# Thus, we have the following features values :
# 'A+' 'A-' 'A' 'B-' 'B' 'B+' 'C+' 'C-' 'C' 'D' 'D+' 'D-' 'F' 'W' 'WU' 'I' nan
#
# Now, we have to remove the Nan value from the dataset.
#
# we are filling or replacing all the Nan values with mode values.

# %% [markdown]
# ## Data preprocessing Steps.

# %% [raw]
# 1- Treating Null Values
# 2- Ordinal Encoding
# 3- Skewness of Dataset
# 4- P-Value Significance

# %% [markdown]
# # Checking For Null Values

# %%
#displaying the count of null values present in each column. 
data.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
#list will return the features that have null values
features_with_null = [features for features in data if data[features].isnull().sum()]
for each_feature in features_with_null:
    data[each_feature] = data[each_feature].fillna(data[each_feature].mode()[0]) #filling each null value present in each column with mode value of its column iteratively.

# %% [markdown]
# # Null Values after getting filled with Mode

# %%
#displaying the count of null values present in each column. The count must be zero now. 
data.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [raw]
# Now, we can see we have zero null values in each column.

# %% [markdown]
# # Storing the updated data to the csv file

# %%
data.to_csv('The_Grades_Dataset_Clean.csv')
data = pd.read_csv('The_Grades_Dataset_Clean.csv')
data
# Out:
#      Unnamed: 0  Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106  \
# 0             0  CS-97001     B-     D+     C-         C     C-     D+      D
# 1             1  CS-97002      A      D     D+         D     B-      C      D
# 2             2  CS-97003      A      B      A        B-     B+      A     B-
# 3             3  CS-97004      D     C+     D+         D      D     A-     D+
# 4             4  CS-97005     A-     A-     A-        B+      A      A     A-
# ..          ...       ...    ...    ...    ...       ...    ...    ...    ...
# 566         566  CS-97567      B      A      A        A-     A+      A     A-
# 567         567  CS-97568     A+      A      A         A      A      A      A
# 568         568  CS-97569      B      A     A-        B+      A      A      A
# 569         569  CS-97570      A     B+      D         A      D     D+     B-
# 570         570  CS-97571      C      D      D         C      C     D+      B
#
#     EL-102  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 0       C-  ...     C-     C-     C-     C-     A-      A     C-      B
# 1        A  ...     D+      D      C      D     A-     B-      C      C
# 2       B+  ...      B      B      A      C      A      A      A     A-
# 3       C-  ...     D+      C     D+     C-     B-      B     C+     C+
# 4       B+  ...     B-     B+     B+     B-     A-      A     A-     A-
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 566     A-  ...     A-     A-      A      A      A     B+     B+      B
# 567     A-  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     C-  ...      D      B      B     C-      D      C      B     B-
# 570     C+  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 0       A-  2.205
# 1        B  2.008
# 2        A  3.608
# 3       C+  1.906
# 4        A  3.448
# ..     ...    ...
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# 569      C  2.193
# 570     C-  1.753
#
# [571 rows x 44 columns]

# %% [markdown]
# # Dropping the unnecessary columns from dataset.

# %%
data.drop(['Seat No.','Unnamed: 0'], axis=1, inplace=True)
data
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
#      ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0    ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1    ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2    ...      B      B      A      C      A      A      A     A-      A  3.608
# 3    ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4    ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 566  ...     A-     A-      A      A      A     B+     B+      B      A  3.798
# 567  ...     B+     B+      A      A     A-      B     A-      C     A-  3.772
# 568  ...     A-      B      A     B+      A      C     B+     A-     A-  3.470
# 569  ...      D      B      B     C-      D      C      B     B-      C  2.193
# 570  ...     C+      C     B-      D      F     C-     B+      D     C-  1.753
#
# [571 rows x 42 columns]

# %% [markdown]
# ### Ordinal Encoding

# %% [raw]
# Next, we convert string data into integer data. we have a natural ranking for grades, hence we can opt for ordinal encoding

# %%
#Seperating the inputs and outputs, so to apply encoding on feature values only. 
Predictors=data.drop("CGPA", axis=1)
target=data["CGPA"]
# print(Predictors)
# print(target)

# %% [markdown]
# # After Encoding

# %%
#Replacing the string values with integer values with respect to their weightage on CGPA
list(Predictors.columns.values)
Col_list=list(Predictors.columns)
for Col in Col_list:
    Predictors[Col]=Predictors[Col].replace('A+',4.0)
    Predictors[Col]=Predictors[Col].replace('A',4.0)
    Predictors[Col]=Predictors[Col].replace('A-',3.7)
    Predictors[Col]=Predictors[Col].replace('B+',3.4)
    Predictors[Col]=Predictors[Col].replace('B',3.0)
    Predictors[Col]=Predictors[Col].replace('B-',2.7)
    Predictors[Col]=Predictors[Col].replace('C+',2.4)
    Predictors[Col]=Predictors[Col].replace('C',2.0)
    Predictors[Col]=Predictors[Col].replace('C-',1.7)
    Predictors[Col]=Predictors[Col].replace('D+',1.4)
    Predictors[Col]=Predictors[Col].replace('D',1.0)
    Predictors[Col]=Predictors[Col].replace('F',0.0)
    Predictors[Col]=Predictors[Col].replace('WU',0.0)
    Predictors[Col]=Predictors[Col].replace('W',0.0)
    Predictors[Col]=Predictors[Col].replace('I',0.0)
    
#Displaying the datatype of each columns.
# type(Predictors)
# Predictors.info()
Predictors
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0       2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7
# 1       4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0
# 2       4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4
# 3       1.0     2.4     1.4        1.0     1.0     3.7     1.4     1.7
# 4       3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566     3.0     4.0     4.0        3.7     4.0     4.0     3.7     3.7
# 567     4.0     4.0     4.0        4.0     4.0     4.0     4.0     3.7
# 568     3.0     4.0     3.7        3.4     4.0     4.0     4.0     4.0
# 569     4.0     3.4     1.0        4.0     1.0     1.4     2.7     1.7
# 570     2.0     1.0     1.0        2.0     2.0     1.4     3.0     2.4
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# 0       2.7     1.7  ...     2.0     1.7     1.7     1.7     1.7     3.7
# 1       1.4     1.0  ...     1.0     1.4     1.0     2.0     1.0     3.7
# 2       3.7     3.7  ...     3.7     3.0     3.0     4.0     2.0     4.0
# 3       1.0     2.4  ...     1.7     1.4     2.0     1.4     1.7     2.7
# 4       4.0     3.7  ...     3.7     2.7     3.4     3.4     2.7     3.7
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 566     4.0     3.4  ...     3.4     3.7     3.7     4.0     4.0     4.0
# 567     4.0     4.0  ...     3.7     3.4     3.4     4.0     4.0     3.7
# 568     4.0     3.0  ...     3.4     3.7     3.0     4.0     3.4     4.0
# 569     2.7     1.7  ...     3.4     1.0     3.0     3.0     1.7     1.0
# 570     2.0     1.4  ...     1.4     2.4     2.0     2.7     1.0     0.0
#
#      CS-414  CS-419  CS-423  CS-412
# 0       4.0     1.7     3.0     3.7
# 1       2.7     2.0     2.0     3.0
# 2       4.0     4.0     3.7     4.0
# 3       3.0     2.4     2.4     2.4
# 4       4.0     3.7     3.7     4.0
# ..      ...     ...     ...     ...
# 566     3.4     3.4     3.0     4.0
# 567     3.0     3.7     2.0     3.7
# 568     2.0     3.4     3.7     3.7
# 569     2.0     3.0     2.7     2.0
# 570     1.7     3.4     1.0     1.7
#
# [571 rows x 41 columns]

# %% [raw]
# Here we are going to check whether our dataset is linear or not.

# %%
sns.set_theme(); np.random.seed(0)
ax = sns.distplot(Predictors)
# Out:
# E:\Programs\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [raw]
# The nature of dataset is non-linear.

# %% [markdown]
# ### Skewness of Dataset.

# %%
from scipy.stats import skew
feature_skewness=skew(Predictors, axis=0, bias=True)
print(feature_skewness)
pos_count, neg_count = 0, 0  
# iterating each number in list
for num in feature_skewness:
      
    # checking condition
    if num >= 0:
        pos_count += 1
  
    else:
        neg_count += 1
print("Positive numbers ", pos_count)
print("Negative numbers ", neg_count)
# Out:
# [-0.88148598 -0.22711828 -1.39018879 -0.58713849 -0.83153589 -1.27153168
#  -0.96794495 -0.82802766 -0.78454195 -0.38067705 -0.65114686 -1.48758566
#  -0.40317514 -1.14052767 -0.67625631 -1.09321583 -0.3336205  -0.54286876
#  -0.12538856 -1.07201324 -0.61959461 -0.37037819 -0.93371456 -0.34728185
#  -0.82499225 -0.65395206 -0.97988792 -0.52339715 -1.26771782 -0.84492034
#  -0.66370123 -0.79671355 -0.546503   -0.41903604 -0.77760205 -0.57648341
#  -2.11671195 -2.15999595 -0.84501684 -0.87423662 -2.08398634]
# Positive numbers  0
# Negative numbers  41

# %% [raw]
# We can see we have neg_count more than pos_count, indicating dataset is positive skewed, unbalanced.

# %% [markdown]
# ### Square Root Transformation - Treating Imbalanced Dataset

# %%
# from scipy.stats import skew
# Predictors_sqrt = np.sqrt(Predictors)
# feature_skewness=skew(Predictors_sqrt, axis=0, bias=True)
# print(feature_skewness)
# pos_count, neg_count = 0, 0  
# # iterating each number in list
# for num in feature_skewness:
      
#     # checking condition
#     if num >= 0:
#         pos_count += 1
  
#     else:
#         neg_count += 1
# print("Positive numbers ", pos_count)
# print("Negative numbers ", neg_count)

# %% [markdown]
# ### Significance of Features - P_Value

# %%
X_incl_const = sm.add_constant(Predictors)

alternate_model = sm.OLS(target, X_incl_const)
results = alternate_model.fit()
#Finding p-values
features_P_value = pd.DataFrame({'p-value': round(results.pvalues, 3)})
features_P_value = features_P_value[features_P_value<0.05]

#dropping insignificant p values. All the listed values have significant features. 
features_P_value=features_P_value.dropna()
features_P_value
# Out:
#            p-value
# PH-121       0.000
# HS-101       0.000
# CY-105       0.000
# HS-105/12    0.009
# CS-105       0.000
# CS-106       0.000
# EL-102       0.000
# EE-119       0.027
# ME-107       0.000
# CS-107       0.044
# HS-205/20    0.001
# MT-224       0.021
# CS-210       0.004
# CS-211       0.036
# CS-214       0.000
# CS-215       0.029
# MT-331       0.003
# CS-301       0.016
# EL-332       0.012
# CS-317       0.000
# CS-421       0.022
# CS-423       0.000

# %% [markdown]
# #### NOTE :

# %% [raw]
# The features that are significant have value less than 0.05 which are listed above. Due to the scope of our problem, we can not remove the insignificant values, as every feature(Subject) has an impact on the CGPA of a student. If the credit hour infromation would have been given, then we could reduce the importance of feature using Ridge regularization which makes the value small rather than making it zero.

# %% [markdown]
# ## 2. Implementation of Models.

# %% [raw]
# Model 1: predict final CGPA based on GPs of first year only.
# Model 2: predict final CGPA based on GPs of first two years.
# Model 3: predict final CGPA based on GPs of first three years.
#
# For each model, implementing the following machine learning algorithms.
#
# 1- Linear Regression.
#
# 2- Regression Tree.
#
# 3- ANN
#
# 4- Polynomial Regression

# %% [markdown]
# # Model 1

# %% [raw]
# Algo 1 - Linear Regression.
# Algo 2 - Regression Tree.
# Algo 3 - Neural Networks.
# Algo 4 - Polynomial Regression.

# %%
Predictor_M1=Predictors.iloc[0:571,0:11] #Slicing
target=data["CGPA"]
Predictor_M1.head(3) # Only 1st year Grades.
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
#
#    ME-107  CS-107
# 0     1.7     1.7
# 1     1.0     3.4
# 2     3.7     2.7

# %% [markdown]
# #### Cross-Validation - Leave one out technique

# %%
# from sklearn.model_selection import LeaveOneOut

# X = [1, 2, 3, 4]
# loo = LeaveOneOut()
# for train, test in loo.split(X):
#     print("%s %s" % (Predictor_M1, target))

# %% [markdown]
# ### Algorithm no. 01 - Linear Regression

# %%
X_train_M1_lr,X_test_M1_lr,Y_train_M1_lr,Y_test_M1_lr = train_test_split(Predictor_M1, target,test_size=0.2,random_state=0) # Implementing 80 and 20 split
r1=LinearRegression()
r1.fit(X_train_M1_lr,Y_train_M1_lr)
print("The training accuracy", r1.score(X_train_M1_lr,Y_train_M1_lr))
print("The testing accuracy",r1.score(X_test_M1_lr,Y_test_M1_lr))
# Out:
# The training accuracy 0.8397211612644766
# The testing accuracy 0.8141336830277861

# %% [markdown]
# ### Algorithm no. 02 - Regression Tree

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M1, target, test_size=0.3)
rt = DecisionTreeRegressor(criterion = 'mse', max_depth=5)
model_r = rt.fit(X_train, y_train)
y_test_pred = model_r.predict(X_test)
y_train_pred = model_r.predict(X_train)
print('R Squared Score of train is:', r2_score(y_train, y_train_pred))
print('R Squared Score of test is:', r2_score(y_test, y_test_pred))
# Out:
# R Squared Score of train is: 0.8536411938121431
# R Squared Score of test is: 0.5820081040793967
# E:\Programs\Python310\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# ### Algorithm no. 03 - ANN

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M1, target, test_size=0.2)
model=models.Sequential()
model.add(layers.Dense(64,activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(1,activation='linear'))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['mean_absolute_error','mean_squared_error'])
history = model.fit(X_train,y_train,epochs=100, batch_size=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 46/46 [==============================] - 1s 6ms/step - loss: 1.3504 - mean_absolute_error: 0.7734 - mean_squared_error: 1.3504 - val_loss: 0.0874 - val_mean_absolute_error: 0.2292 - val_mean_squared_error: 0.0874
# Epoch 2/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0850 - mean_absolute_error: 0.2238 - mean_squared_error: 0.0850 - val_loss: 0.0657 - val_mean_absolute_error: 0.2013 - val_mean_squared_error: 0.0657
# Epoch 3/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0732 - mean_absolute_error: 0.2130 - mean_squared_error: 0.0732 - val_loss: 0.0725 - val_mean_absolute_error: 0.2140 - val_mean_squared_error: 0.0725
# Epoch 4/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0675 - mean_absolute_error: 0.2060 - mean_squared_error: 0.0675 - val_loss: 0.0566 - val_mean_absolute_error: 0.1837 - val_mean_squared_error: 0.0566
# Epoch 5/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0617 - mean_absolute_error: 0.1961 - mean_squared_error: 0.0617 - val_loss: 0.0512 - val_mean_absolute_error: 0.1751 - val_mean_squared_error: 0.0512
# Epoch 6/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0633 - mean_absolute_error: 0.2023 - mean_squared_error: 0.0633 - val_loss: 0.0539 - val_mean_absolute_error: 0.1734 - val_mean_squared_error: 0.0539
# Epoch 7/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0569 - mean_absolute_error: 0.1876 - mean_squared_error: 0.0569 - val_loss: 0.0539 - val_mean_absolute_error: 0.1797 - val_mean_squared_error: 0.0539
# Epoch 8/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0537 - mean_absolute_error: 0.1853 - mean_squared_error: 0.0537 - val_loss: 0.0577 - val_mean_absolute_error: 0.1777 - val_mean_squared_error: 0.0577
# Epoch 9/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0510 - mean_absolute_error: 0.1794 - mean_squared_error: 0.0510 - val_loss: 0.0541 - val_mean_absolute_error: 0.1746 - val_mean_squared_error: 0.0541
# Epoch 10/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0490 - mean_absolute_error: 0.1726 - mean_squared_error: 0.0490 - val_loss: 0.0552 - val_mean_absolute_error: 0.1744 - val_mean_squared_error: 0.0552
# Epoch 11/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0473 - mean_absolute_error: 0.1737 - mean_squared_error: 0.0473 - val_loss: 0.0604 - val_mean_absolute_error: 0.1869 - val_mean_squared_error: 0.0604
# Epoch 12/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0461 - mean_absolute_error: 0.1724 - mean_squared_error: 0.0461 - val_loss: 0.0564 - val_mean_absolute_error: 0.1789 - val_mean_squared_error: 0.0564
# Epoch 13/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0481 - mean_absolute_error: 0.1739 - mean_squared_error: 0.0481 - val_loss: 0.0597 - val_mean_absolute_error: 0.1830 - val_mean_squared_error: 0.0597
# Epoch 14/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0479 - mean_absolute_error: 0.1715 - mean_squared_error: 0.0479 - val_loss: 0.0572 - val_mean_absolute_error: 0.1793 - val_mean_squared_error: 0.0572
# Epoch 15/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0420 - mean_absolute_error: 0.1664 - mean_squared_error: 0.0420 - val_loss: 0.0592 - val_mean_absolute_error: 0.1889 - val_mean_squared_error: 0.0592
# Epoch 16/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0451 - mean_absolute_error: 0.1691 - mean_squared_error: 0.0451 - val_loss: 0.0635 - val_mean_absolute_error: 0.2038 - val_mean_squared_error: 0.0635
# Epoch 17/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0421 - mean_absolute_error: 0.1640 - mean_squared_error: 0.0421 - val_loss: 0.0553 - val_mean_absolute_error: 0.1735 - val_mean_squared_error: 0.0553
# Epoch 18/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0420 - mean_absolute_error: 0.1597 - mean_squared_error: 0.0420 - val_loss: 0.0664 - val_mean_absolute_error: 0.1928 - val_mean_squared_error: 0.0664
# Epoch 19/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0404 - mean_absolute_error: 0.1584 - mean_squared_error: 0.0404 - val_loss: 0.0663 - val_mean_absolute_error: 0.2062 - val_mean_squared_error: 0.0663
# Epoch 20/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0462 - mean_absolute_error: 0.1704 - mean_squared_error: 0.0462 - val_loss: 0.1012 - val_mean_absolute_error: 0.2596 - val_mean_squared_error: 0.1012
# Epoch 21/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0463 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0463 - val_loss: 0.0680 - val_mean_absolute_error: 0.2031 - val_mean_squared_error: 0.0680
# Epoch 22/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0457 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0457 - val_loss: 0.0583 - val_mean_absolute_error: 0.1841 - val_mean_squared_error: 0.0583
# Epoch 23/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0400 - mean_absolute_error: 0.1576 - mean_squared_error: 0.0400 - val_loss: 0.0553 - val_mean_absolute_error: 0.1778 - val_mean_squared_error: 0.0553
# Epoch 24/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0368 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0368 - val_loss: 0.0892 - val_mean_absolute_error: 0.2502 - val_mean_squared_error: 0.0892
# Epoch 25/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0399 - mean_absolute_error: 0.1563 - mean_squared_error: 0.0399 - val_loss: 0.0678 - val_mean_absolute_error: 0.1997 - val_mean_squared_error: 0.0678
# Epoch 26/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0360 - mean_absolute_error: 0.1488 - mean_squared_error: 0.0360 - val_loss: 0.0567 - val_mean_absolute_error: 0.1779 - val_mean_squared_error: 0.0567
# Epoch 27/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0378 - mean_absolute_error: 0.1519 - mean_squared_error: 0.0378 - val_loss: 0.0595 - val_mean_absolute_error: 0.1889 - val_mean_squared_error: 0.0595
# Epoch 28/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0363 - mean_absolute_error: 0.1522 - mean_squared_error: 0.0363 - val_loss: 0.0602 - val_mean_absolute_error: 0.1799 - val_mean_squared_error: 0.0602
# Epoch 29/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0398 - mean_absolute_error: 0.1577 - mean_squared_error: 0.0398 - val_loss: 0.0611 - val_mean_absolute_error: 0.1853 - val_mean_squared_error: 0.0611
# Epoch 30/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0409 - mean_absolute_error: 0.1575 - mean_squared_error: 0.0409 - val_loss: 0.0669 - val_mean_absolute_error: 0.1928 - val_mean_squared_error: 0.0669
# Epoch 31/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0374 - mean_absolute_error: 0.1525 - mean_squared_error: 0.0374 - val_loss: 0.0624 - val_mean_absolute_error: 0.1905 - val_mean_squared_error: 0.0624
# Epoch 32/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0418 - mean_absolute_error: 0.1589 - mean_squared_error: 0.0418 - val_loss: 0.0652 - val_mean_absolute_error: 0.1900 - val_mean_squared_error: 0.0652
# Epoch 33/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0405 - mean_absolute_error: 0.1557 - mean_squared_error: 0.0405 - val_loss: 0.0750 - val_mean_absolute_error: 0.2103 - val_mean_squared_error: 0.0750
# Epoch 34/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0369 - mean_absolute_error: 0.1491 - mean_squared_error: 0.0369 - val_loss: 0.0616 - val_mean_absolute_error: 0.1859 - val_mean_squared_error: 0.0616
# Epoch 35/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0344 - mean_absolute_error: 0.1433 - mean_squared_error: 0.0344 - val_loss: 0.0809 - val_mean_absolute_error: 0.2273 - val_mean_squared_error: 0.0809
# Epoch 36/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0362 - mean_absolute_error: 0.1519 - mean_squared_error: 0.0362 - val_loss: 0.0781 - val_mean_absolute_error: 0.2259 - val_mean_squared_error: 0.0781
# Epoch 37/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0401 - mean_absolute_error: 0.1613 - mean_squared_error: 0.0401 - val_loss: 0.0610 - val_mean_absolute_error: 0.1863 - val_mean_squared_error: 0.0610
# Epoch 38/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0349 - mean_absolute_error: 0.1452 - mean_squared_error: 0.0349 - val_loss: 0.0673 - val_mean_absolute_error: 0.1954 - val_mean_squared_error: 0.0673
# Epoch 39/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0364 - mean_absolute_error: 0.1511 - mean_squared_error: 0.0364 - val_loss: 0.0630 - val_mean_absolute_error: 0.1866 - val_mean_squared_error: 0.0630
# Epoch 40/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0311 - mean_absolute_error: 0.1381 - mean_squared_error: 0.0311 - val_loss: 0.0638 - val_mean_absolute_error: 0.1925 - val_mean_squared_error: 0.0638
# Epoch 41/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0439 - mean_absolute_error: 0.1651 - mean_squared_error: 0.0439 - val_loss: 0.1067 - val_mean_absolute_error: 0.2682 - val_mean_squared_error: 0.1067
# Epoch 42/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0434 - mean_absolute_error: 0.1662 - mean_squared_error: 0.0434 - val_loss: 0.0626 - val_mean_absolute_error: 0.1834 - val_mean_squared_error: 0.0626
# Epoch 43/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0341 - mean_absolute_error: 0.1437 - mean_squared_error: 0.0341 - val_loss: 0.0637 - val_mean_absolute_error: 0.1965 - val_mean_squared_error: 0.0637
# Epoch 44/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0317 - mean_absolute_error: 0.1388 - mean_squared_error: 0.0317 - val_loss: 0.0717 - val_mean_absolute_error: 0.2141 - val_mean_squared_error: 0.0717
# Epoch 45/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0305 - mean_absolute_error: 0.1361 - mean_squared_error: 0.0305 - val_loss: 0.0724 - val_mean_absolute_error: 0.2020 - val_mean_squared_error: 0.0724
# Epoch 46/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0314 - mean_absolute_error: 0.1384 - mean_squared_error: 0.0314 - val_loss: 0.0688 - val_mean_absolute_error: 0.1960 - val_mean_squared_error: 0.0688
# Epoch 47/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0298 - mean_absolute_error: 0.1331 - mean_squared_error: 0.0298 - val_loss: 0.0694 - val_mean_absolute_error: 0.2021 - val_mean_squared_error: 0.0694
# Epoch 48/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0295 - mean_absolute_error: 0.1315 - mean_squared_error: 0.0295 - val_loss: 0.0729 - val_mean_absolute_error: 0.2054 - val_mean_squared_error: 0.0729
# Epoch 49/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0347 - mean_absolute_error: 0.1456 - mean_squared_error: 0.0347 - val_loss: 0.0730 - val_mean_absolute_error: 0.2049 - val_mean_squared_error: 0.0730
# Epoch 50/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1511 - mean_squared_error: 0.0367 - val_loss: 0.0636 - val_mean_absolute_error: 0.1852 - val_mean_squared_error: 0.0636
# Epoch 51/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0323 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0323 - val_loss: 0.0787 - val_mean_absolute_error: 0.2102 - val_mean_squared_error: 0.0787
# Epoch 52/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0373 - mean_absolute_error: 0.1506 - mean_squared_error: 0.0373 - val_loss: 0.0658 - val_mean_absolute_error: 0.1910 - val_mean_squared_error: 0.0658
# Epoch 53/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0305 - mean_absolute_error: 0.1362 - mean_squared_error: 0.0305 - val_loss: 0.0682 - val_mean_absolute_error: 0.1993 - val_mean_squared_error: 0.0682
# Epoch 54/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0309 - mean_absolute_error: 0.1366 - mean_squared_error: 0.0309 - val_loss: 0.0780 - val_mean_absolute_error: 0.2104 - val_mean_squared_error: 0.0780
# Epoch 55/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0301 - mean_absolute_error: 0.1349 - mean_squared_error: 0.0301 - val_loss: 0.0667 - val_mean_absolute_error: 0.1894 - val_mean_squared_error: 0.0667
# Epoch 56/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0296 - mean_absolute_error: 0.1336 - mean_squared_error: 0.0296 - val_loss: 0.0802 - val_mean_absolute_error: 0.2160 - val_mean_squared_error: 0.0802
# Epoch 57/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0366 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0366 - val_loss: 0.0874 - val_mean_absolute_error: 0.2329 - val_mean_squared_error: 0.0874
# Epoch 58/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0281 - mean_absolute_error: 0.1310 - mean_squared_error: 0.0281 - val_loss: 0.0969 - val_mean_absolute_error: 0.2569 - val_mean_squared_error: 0.0969
# Epoch 59/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0319 - mean_absolute_error: 0.1402 - mean_squared_error: 0.0319 - val_loss: 0.0679 - val_mean_absolute_error: 0.2004 - val_mean_squared_error: 0.0679
# Epoch 60/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0304 - mean_absolute_error: 0.1347 - mean_squared_error: 0.0304 - val_loss: 0.0688 - val_mean_absolute_error: 0.2038 - val_mean_squared_error: 0.0688
# Epoch 61/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0297 - mean_absolute_error: 0.1331 - mean_squared_error: 0.0297 - val_loss: 0.0978 - val_mean_absolute_error: 0.2612 - val_mean_squared_error: 0.0978
# Epoch 62/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0362 - mean_absolute_error: 0.1499 - mean_squared_error: 0.0362 - val_loss: 0.0760 - val_mean_absolute_error: 0.2129 - val_mean_squared_error: 0.0760
# Epoch 63/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0282 - mean_absolute_error: 0.1303 - mean_squared_error: 0.0282 - val_loss: 0.0723 - val_mean_absolute_error: 0.2077 - val_mean_squared_error: 0.0723
# Epoch 64/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0270 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0270 - val_loss: 0.0689 - val_mean_absolute_error: 0.1963 - val_mean_squared_error: 0.0689
# Epoch 65/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0274 - mean_absolute_error: 0.1283 - mean_squared_error: 0.0274 - val_loss: 0.0799 - val_mean_absolute_error: 0.2159 - val_mean_squared_error: 0.0799
# Epoch 66/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0290 - mean_absolute_error: 0.1307 - mean_squared_error: 0.0290 - val_loss: 0.0769 - val_mean_absolute_error: 0.2080 - val_mean_squared_error: 0.0769
# Epoch 67/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0296 - mean_absolute_error: 0.1337 - mean_squared_error: 0.0296 - val_loss: 0.0670 - val_mean_absolute_error: 0.1933 - val_mean_squared_error: 0.0670
# Epoch 68/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0325 - mean_absolute_error: 0.1407 - mean_squared_error: 0.0325 - val_loss: 0.0727 - val_mean_absolute_error: 0.2103 - val_mean_squared_error: 0.0727
# Epoch 69/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0263 - mean_absolute_error: 0.1259 - mean_squared_error: 0.0263 - val_loss: 0.0700 - val_mean_absolute_error: 0.1961 - val_mean_squared_error: 0.0700
# Epoch 70/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0314 - mean_absolute_error: 0.1404 - mean_squared_error: 0.0314 - val_loss: 0.0710 - val_mean_absolute_error: 0.2028 - val_mean_squared_error: 0.0710
# Epoch 71/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0295 - mean_absolute_error: 0.1322 - mean_squared_error: 0.0295 - val_loss: 0.0643 - val_mean_absolute_error: 0.1916 - val_mean_squared_error: 0.0643
# Epoch 72/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0256 - mean_absolute_error: 0.1233 - mean_squared_error: 0.0256 - val_loss: 0.0823 - val_mean_absolute_error: 0.2215 - val_mean_squared_error: 0.0823
# Epoch 73/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0259 - mean_absolute_error: 0.1223 - mean_squared_error: 0.0259 - val_loss: 0.0778 - val_mean_absolute_error: 0.2171 - val_mean_squared_error: 0.0778
# Epoch 74/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0286 - mean_absolute_error: 0.1307 - mean_squared_error: 0.0286 - val_loss: 0.0745 - val_mean_absolute_error: 0.2047 - val_mean_squared_error: 0.0745
# Epoch 75/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0295 - mean_absolute_error: 0.1297 - mean_squared_error: 0.0295 - val_loss: 0.0750 - val_mean_absolute_error: 0.2060 - val_mean_squared_error: 0.0750
# Epoch 76/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0271 - mean_absolute_error: 0.1288 - mean_squared_error: 0.0271 - val_loss: 0.0657 - val_mean_absolute_error: 0.1942 - val_mean_squared_error: 0.0657
# Epoch 77/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0323 - mean_absolute_error: 0.1389 - mean_squared_error: 0.0323 - val_loss: 0.0749 - val_mean_absolute_error: 0.2058 - val_mean_squared_error: 0.0749
# Epoch 78/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0278 - mean_absolute_error: 0.1283 - mean_squared_error: 0.0278 - val_loss: 0.0797 - val_mean_absolute_error: 0.2249 - val_mean_squared_error: 0.0797
# Epoch 79/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0290 - mean_absolute_error: 0.1323 - mean_squared_error: 0.0290 - val_loss: 0.0961 - val_mean_absolute_error: 0.2365 - val_mean_squared_error: 0.0961
# Epoch 80/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0326 - mean_absolute_error: 0.1441 - mean_squared_error: 0.0326 - val_loss: 0.0755 - val_mean_absolute_error: 0.2137 - val_mean_squared_error: 0.0755
# Epoch 81/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0259 - mean_absolute_error: 0.1292 - mean_squared_error: 0.0259 - val_loss: 0.0826 - val_mean_absolute_error: 0.2180 - val_mean_squared_error: 0.0826
# Epoch 82/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_absolute_error: 0.1165 - mean_squared_error: 0.0238 - val_loss: 0.0751 - val_mean_absolute_error: 0.2043 - val_mean_squared_error: 0.0751
# Epoch 83/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0268 - mean_absolute_error: 0.1271 - mean_squared_error: 0.0268 - val_loss: 0.0775 - val_mean_absolute_error: 0.2115 - val_mean_squared_error: 0.0775
# Epoch 84/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0250 - mean_absolute_error: 0.1206 - mean_squared_error: 0.0250 - val_loss: 0.0842 - val_mean_absolute_error: 0.2326 - val_mean_squared_error: 0.0842
# Epoch 85/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0304 - mean_absolute_error: 0.1385 - mean_squared_error: 0.0304 - val_loss: 0.0907 - val_mean_absolute_error: 0.2492 - val_mean_squared_error: 0.0907
# Epoch 86/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0294 - mean_absolute_error: 0.1322 - mean_squared_error: 0.0294 - val_loss: 0.0752 - val_mean_absolute_error: 0.2111 - val_mean_squared_error: 0.0752
# Epoch 87/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0255 - mean_absolute_error: 0.1247 - mean_squared_error: 0.0255 - val_loss: 0.0766 - val_mean_absolute_error: 0.2178 - val_mean_squared_error: 0.0766
# Epoch 88/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0222 - mean_absolute_error: 0.1152 - mean_squared_error: 0.0222 - val_loss: 0.0792 - val_mean_absolute_error: 0.2135 - val_mean_squared_error: 0.0792
# Epoch 89/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0285 - mean_absolute_error: 0.1285 - mean_squared_error: 0.0285 - val_loss: 0.0948 - val_mean_absolute_error: 0.2382 - val_mean_squared_error: 0.0948
# Epoch 90/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0273 - mean_absolute_error: 0.1275 - mean_squared_error: 0.0273 - val_loss: 0.0699 - val_mean_absolute_error: 0.2000 - val_mean_squared_error: 0.0699
# Epoch 91/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_absolute_error: 0.1170 - mean_squared_error: 0.0235 - val_loss: 0.0799 - val_mean_absolute_error: 0.2126 - val_mean_squared_error: 0.0799
# Epoch 92/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0277 - mean_absolute_error: 0.1291 - mean_squared_error: 0.0277 - val_loss: 0.0817 - val_mean_absolute_error: 0.2228 - val_mean_squared_error: 0.0817
# Epoch 93/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0271 - mean_absolute_error: 0.1285 - mean_squared_error: 0.0271 - val_loss: 0.0728 - val_mean_absolute_error: 0.2060 - val_mean_squared_error: 0.0728
# Epoch 94/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_absolute_error: 0.1257 - mean_squared_error: 0.0254 - val_loss: 0.0756 - val_mean_absolute_error: 0.2066 - val_mean_squared_error: 0.0756
# Epoch 95/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0249 - mean_absolute_error: 0.1208 - mean_squared_error: 0.0249 - val_loss: 0.0751 - val_mean_absolute_error: 0.2193 - val_mean_squared_error: 0.0751
# Epoch 96/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.1165 - mean_squared_error: 0.0234 - val_loss: 0.0922 - val_mean_absolute_error: 0.2393 - val_mean_squared_error: 0.0922
# Epoch 97/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0213 - mean_absolute_error: 0.1131 - mean_squared_error: 0.0213 - val_loss: 0.0775 - val_mean_absolute_error: 0.2130 - val_mean_squared_error: 0.0775
# Epoch 98/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0226 - mean_absolute_error: 0.1136 - mean_squared_error: 0.0226 - val_loss: 0.0778 - val_mean_absolute_error: 0.2045 - val_mean_squared_error: 0.0778
# Epoch 99/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0266 - mean_absolute_error: 0.1242 - mean_squared_error: 0.0266 - val_loss: 0.0835 - val_mean_absolute_error: 0.2286 - val_mean_squared_error: 0.0835
# Epoch 100/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0398 - mean_absolute_error: 0.1555 - mean_squared_error: 0.0398 - val_loss: 0.0897 - val_mean_absolute_error: 0.2531 - val_mean_squared_error: 0.0897

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.xlabel("Epochs")
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.show()

# %%
test_predictions=model.predict(X_test)
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0897 - mean_absolute_error: 0.2531 - mean_squared_error: 0.0897
# [0.08969106525182724, 0.2531045973300934, 0.08969106525182724]

# %% [markdown]
# ### Algorithm no. 04 - Polynomial Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M1, target, test_size=0.2, random_state=10)
deg=2 # Degree 9 is giving the error of insufficient memory
X_train_poly2=PolynomialFeatures(degree=deg).fit_transform(X_train)
X_train_poly2=pd.DataFrame(X_train_poly2)
X_train_poly2=X_train_poly2.drop([0],axis=1)
model5=LinearRegression()
model5.fit(X_train_poly2,y_train)

print('Training data r-square:', model5.score(X_train_poly2, y_train))
X_test_poly2=PolynomialFeatures(degree=deg).fit_transform(X_test)
X_test_poly2=pd.DataFrame(X_test_poly2)
X_test_poly2=X_test_poly2.drop([0],axis=1)
print('Test data r-square:', model5.score(X_test_poly2, y_test))
# print('Number of non-zero features:',np.sum(model5.coef_ != 0))
# Out:
# Training data r-square: 0.9083469239333103
# Test data r-square: 0.792020371849271

# %% [markdown]
# # Model 2

# %%
Predictor_M2=Predictors.iloc[0:571,0:22] #Slicing
Predictor_M2 # Only 1st & 2nd year Grades.
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0       2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7
# 1       4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0
# 2       4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4
# 3       1.0     2.4     1.4        1.0     1.0     3.7     1.4     1.7
# 4       3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566     3.0     4.0     4.0        3.7     4.0     4.0     3.7     3.7
# 567     4.0     4.0     4.0        4.0     4.0     4.0     4.0     3.7
# 568     3.0     4.0     3.7        3.4     4.0     4.0     4.0     4.0
# 569     4.0     3.4     1.0        4.0     1.0     1.4     2.7     1.7
# 570     2.0     1.0     1.0        2.0     2.0     1.4     3.0     2.4
#
#      EE-119  ME-107  ...  MT-222  EE-222  MT-224  CS-210  CS-211  CS-203  \
# 0       2.7     1.7  ...     1.0     3.7     2.7     2.4     1.4     1.4
# 1       1.4     1.0  ...     2.7     1.7     1.4     1.4     1.0     2.0
# 2       3.7     3.7  ...     4.0     4.0     4.0     4.0     4.0     4.0
# 3       1.0     2.4  ...     1.4     2.7     1.0     2.0     3.4     2.4
# 4       4.0     3.7  ...     4.0     3.7     3.7     3.7     2.7     4.0
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 566     4.0     3.4  ...     4.0     4.0     4.0     4.0     4.0     4.0
# 567     4.0     4.0  ...     2.4     3.7     3.0     4.0     4.0     4.0
# 568     4.0     3.0  ...     3.0     3.4     3.0     3.7     4.0     3.4
# 569     2.7     1.7  ...     1.0     1.0     3.0     2.7     3.0     2.7
# 570     2.0     1.4  ...     1.7     3.4     1.4     3.4     1.7     3.0
#
#      CS-214  EE-217  CS-212  CS-215
# 0       1.0     4.0     1.0     1.7
# 1       1.0     2.7     2.0     1.0
# 2       3.7     4.0     3.7     4.0
# 3       1.0     1.4     1.0     1.0
# 4       3.7     4.0     3.7     3.7
# ..      ...     ...     ...     ...
# 566     4.0     4.0     3.0     3.7
# 567     4.0     4.0     4.0     3.0
# 568     3.0     4.0     3.4     3.0
# 569     2.0     2.7     1.4     1.4
# 570     1.4     1.7     2.0     1.4
#
# [571 rows x 22 columns]

# %% [markdown]
# ### Algorithm no. 01 - Linear Regression

# %%
X_train_M2_lr,X_test_M2_lr,Y_train_M2_lr,Y_test_M2_lr = train_test_split(Predictor_M2, target,test_size=0.2,random_state=0) # Implementing 80 and 20 split
r2=LinearRegression()
r2.fit(X_train_M2_lr,Y_train_M2_lr)
print("The training accuracy", r2.score(X_train_M2_lr,Y_train_M2_lr))
print("The testing accuracy",r2.score(X_test_M2_lr,Y_test_M2_lr))
# Out:
# The training accuracy 0.9088336931042303
# The testing accuracy 0.9066851498286942

# %% [markdown]
# ### Algorithm no. 02 - Regression Tree

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M2, target, test_size=0.3)
rt = DecisionTreeRegressor(criterion = 'mse', max_depth=5)
model_r = rt.fit(X_train, y_train)
y_test_pred = model_r.predict(X_test)
y_train_pred = model_r.predict(X_train)
print('R Squared Score of train is:', r2_score(y_train, y_train_pred))
print('R Squared Score of test is:', r2_score(y_test, y_test_pred))
# Out:
# R Squared Score of train is: 0.9133454640658888
# R Squared Score of test is: 0.7311201882028819
# E:\Programs\Python310\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# ### Algorithm no. 03 - ANN

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M1, target, test_size=0.2)
model=models.Sequential()
model.add(layers.Dense(64,activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(1,activation='linear'))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['mean_absolute_error','mean_squared_error'])
history = model.fit(X_train,y_train,epochs=100, batch_size=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 46/46 [==============================] - 1s 6ms/step - loss: 0.9978 - mean_absolute_error: 0.6466 - mean_squared_error: 0.9978 - val_loss: 0.0989 - val_mean_absolute_error: 0.2521 - val_mean_squared_error: 0.0989
# Epoch 2/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0852 - mean_absolute_error: 0.2245 - mean_squared_error: 0.0852 - val_loss: 0.0744 - val_mean_absolute_error: 0.2136 - val_mean_squared_error: 0.0744
# Epoch 3/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0739 - mean_absolute_error: 0.2109 - mean_squared_error: 0.0739 - val_loss: 0.0731 - val_mean_absolute_error: 0.2156 - val_mean_squared_error: 0.0731
# Epoch 4/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0674 - mean_absolute_error: 0.2042 - mean_squared_error: 0.0674 - val_loss: 0.0710 - val_mean_absolute_error: 0.2158 - val_mean_squared_error: 0.0710
# Epoch 5/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0636 - mean_absolute_error: 0.1977 - mean_squared_error: 0.0636 - val_loss: 0.0630 - val_mean_absolute_error: 0.1941 - val_mean_squared_error: 0.0630
# Epoch 6/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0586 - mean_absolute_error: 0.1875 - mean_squared_error: 0.0586 - val_loss: 0.0611 - val_mean_absolute_error: 0.1981 - val_mean_squared_error: 0.0611
# Epoch 7/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0575 - mean_absolute_error: 0.1891 - mean_squared_error: 0.0575 - val_loss: 0.0604 - val_mean_absolute_error: 0.1981 - val_mean_squared_error: 0.0604
# Epoch 8/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0541 - mean_absolute_error: 0.1845 - mean_squared_error: 0.0541 - val_loss: 0.0593 - val_mean_absolute_error: 0.1845 - val_mean_squared_error: 0.0593
# Epoch 9/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0526 - mean_absolute_error: 0.1819 - mean_squared_error: 0.0526 - val_loss: 0.0764 - val_mean_absolute_error: 0.2326 - val_mean_squared_error: 0.0764
# Epoch 10/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0541 - mean_absolute_error: 0.1866 - mean_squared_error: 0.0541 - val_loss: 0.0593 - val_mean_absolute_error: 0.1939 - val_mean_squared_error: 0.0593
# Epoch 11/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0508 - mean_absolute_error: 0.1777 - mean_squared_error: 0.0508 - val_loss: 0.0619 - val_mean_absolute_error: 0.2065 - val_mean_squared_error: 0.0619
# Epoch 12/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0499 - mean_absolute_error: 0.1763 - mean_squared_error: 0.0499 - val_loss: 0.0587 - val_mean_absolute_error: 0.1965 - val_mean_squared_error: 0.0587
# Epoch 13/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0480 - mean_absolute_error: 0.1736 - mean_squared_error: 0.0480 - val_loss: 0.0572 - val_mean_absolute_error: 0.1817 - val_mean_squared_error: 0.0572
# Epoch 14/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0455 - mean_absolute_error: 0.1689 - mean_squared_error: 0.0455 - val_loss: 0.0590 - val_mean_absolute_error: 0.1828 - val_mean_squared_error: 0.0590
# Epoch 15/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0447 - mean_absolute_error: 0.1662 - mean_squared_error: 0.0447 - val_loss: 0.0622 - val_mean_absolute_error: 0.2083 - val_mean_squared_error: 0.0622
# Epoch 16/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0468 - mean_absolute_error: 0.1720 - mean_squared_error: 0.0468 - val_loss: 0.1034 - val_mean_absolute_error: 0.2571 - val_mean_squared_error: 0.1034
# Epoch 17/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0528 - mean_absolute_error: 0.1774 - mean_squared_error: 0.0528 - val_loss: 0.0613 - val_mean_absolute_error: 0.1973 - val_mean_squared_error: 0.0613
# Epoch 18/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0484 - mean_absolute_error: 0.1747 - mean_squared_error: 0.0484 - val_loss: 0.0548 - val_mean_absolute_error: 0.1867 - val_mean_squared_error: 0.0548
# Epoch 19/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0439 - mean_absolute_error: 0.1632 - mean_squared_error: 0.0439 - val_loss: 0.0546 - val_mean_absolute_error: 0.1841 - val_mean_squared_error: 0.0546
# Epoch 20/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0443 - mean_absolute_error: 0.1641 - mean_squared_error: 0.0443 - val_loss: 0.0591 - val_mean_absolute_error: 0.2028 - val_mean_squared_error: 0.0591
# Epoch 21/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0497 - mean_absolute_error: 0.1785 - mean_squared_error: 0.0497 - val_loss: 0.0842 - val_mean_absolute_error: 0.2203 - val_mean_squared_error: 0.0842
# Epoch 22/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0430 - mean_absolute_error: 0.1601 - mean_squared_error: 0.0430 - val_loss: 0.0567 - val_mean_absolute_error: 0.1975 - val_mean_squared_error: 0.0567
# Epoch 23/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0435 - mean_absolute_error: 0.1649 - mean_squared_error: 0.0435 - val_loss: 0.0811 - val_mean_absolute_error: 0.2429 - val_mean_squared_error: 0.0811
# Epoch 24/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0467 - mean_absolute_error: 0.1672 - mean_squared_error: 0.0467 - val_loss: 0.0569 - val_mean_absolute_error: 0.1902 - val_mean_squared_error: 0.0569
# Epoch 25/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0483 - mean_absolute_error: 0.1728 - mean_squared_error: 0.0483 - val_loss: 0.0660 - val_mean_absolute_error: 0.1897 - val_mean_squared_error: 0.0660
# Epoch 26/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0450 - mean_absolute_error: 0.1653 - mean_squared_error: 0.0450 - val_loss: 0.0646 - val_mean_absolute_error: 0.2076 - val_mean_squared_error: 0.0646
# Epoch 27/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0439 - mean_absolute_error: 0.1645 - mean_squared_error: 0.0439 - val_loss: 0.0690 - val_mean_absolute_error: 0.2223 - val_mean_squared_error: 0.0690
# Epoch 28/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0409 - mean_absolute_error: 0.1599 - mean_squared_error: 0.0409 - val_loss: 0.0551 - val_mean_absolute_error: 0.1776 - val_mean_squared_error: 0.0551
# Epoch 29/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0445 - mean_absolute_error: 0.1665 - mean_squared_error: 0.0445 - val_loss: 0.0567 - val_mean_absolute_error: 0.1893 - val_mean_squared_error: 0.0567
# Epoch 30/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0396 - mean_absolute_error: 0.1545 - mean_squared_error: 0.0396 - val_loss: 0.0559 - val_mean_absolute_error: 0.1862 - val_mean_squared_error: 0.0559
# Epoch 31/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0439 - mean_absolute_error: 0.1645 - mean_squared_error: 0.0439 - val_loss: 0.0533 - val_mean_absolute_error: 0.1828 - val_mean_squared_error: 0.0533
# Epoch 32/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0430 - mean_absolute_error: 0.1649 - mean_squared_error: 0.0430 - val_loss: 0.0557 - val_mean_absolute_error: 0.1867 - val_mean_squared_error: 0.0557
# Epoch 33/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0396 - mean_absolute_error: 0.1546 - mean_squared_error: 0.0396 - val_loss: 0.0641 - val_mean_absolute_error: 0.2076 - val_mean_squared_error: 0.0641
# Epoch 34/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0406 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0406 - val_loss: 0.0580 - val_mean_absolute_error: 0.1833 - val_mean_squared_error: 0.0580
# Epoch 35/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0378 - mean_absolute_error: 0.1523 - mean_squared_error: 0.0378 - val_loss: 0.0574 - val_mean_absolute_error: 0.1914 - val_mean_squared_error: 0.0574
# Epoch 36/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0408 - mean_absolute_error: 0.1567 - mean_squared_error: 0.0408 - val_loss: 0.0627 - val_mean_absolute_error: 0.1834 - val_mean_squared_error: 0.0627
# Epoch 37/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0387 - mean_absolute_error: 0.1555 - mean_squared_error: 0.0387 - val_loss: 0.0610 - val_mean_absolute_error: 0.1820 - val_mean_squared_error: 0.0610
# Epoch 38/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0411 - mean_absolute_error: 0.1550 - mean_squared_error: 0.0411 - val_loss: 0.0633 - val_mean_absolute_error: 0.1891 - val_mean_squared_error: 0.0633
# Epoch 39/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_absolute_error: 0.1508 - mean_squared_error: 0.0386 - val_loss: 0.0552 - val_mean_absolute_error: 0.1838 - val_mean_squared_error: 0.0552
# Epoch 40/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0357 - mean_absolute_error: 0.1445 - mean_squared_error: 0.0357 - val_loss: 0.0592 - val_mean_absolute_error: 0.1960 - val_mean_squared_error: 0.0592
# Epoch 41/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0374 - mean_absolute_error: 0.1502 - mean_squared_error: 0.0374 - val_loss: 0.0641 - val_mean_absolute_error: 0.1893 - val_mean_squared_error: 0.0641
# Epoch 42/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0385 - mean_absolute_error: 0.1532 - mean_squared_error: 0.0385 - val_loss: 0.0652 - val_mean_absolute_error: 0.2115 - val_mean_squared_error: 0.0652
# Epoch 43/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_absolute_error: 0.1556 - mean_squared_error: 0.0386 - val_loss: 0.0615 - val_mean_absolute_error: 0.1822 - val_mean_squared_error: 0.0615
# Epoch 44/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0370 - mean_absolute_error: 0.1468 - mean_squared_error: 0.0370 - val_loss: 0.0589 - val_mean_absolute_error: 0.1850 - val_mean_squared_error: 0.0589
# Epoch 45/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0350 - mean_absolute_error: 0.1451 - mean_squared_error: 0.0350 - val_loss: 0.0605 - val_mean_absolute_error: 0.1952 - val_mean_squared_error: 0.0605
# Epoch 46/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0388 - mean_absolute_error: 0.1512 - mean_squared_error: 0.0388 - val_loss: 0.0600 - val_mean_absolute_error: 0.1884 - val_mean_squared_error: 0.0600
# Epoch 47/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0362 - mean_absolute_error: 0.1486 - mean_squared_error: 0.0362 - val_loss: 0.0591 - val_mean_absolute_error: 0.1958 - val_mean_squared_error: 0.0591
# Epoch 48/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0344 - mean_absolute_error: 0.1419 - mean_squared_error: 0.0344 - val_loss: 0.0588 - val_mean_absolute_error: 0.1872 - val_mean_squared_error: 0.0588
# Epoch 49/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0346 - mean_absolute_error: 0.1431 - mean_squared_error: 0.0346 - val_loss: 0.0626 - val_mean_absolute_error: 0.2014 - val_mean_squared_error: 0.0626
# Epoch 50/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0336 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0336 - val_loss: 0.0554 - val_mean_absolute_error: 0.1947 - val_mean_squared_error: 0.0554
# Epoch 51/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0341 - mean_absolute_error: 0.1406 - mean_squared_error: 0.0341 - val_loss: 0.0594 - val_mean_absolute_error: 0.1927 - val_mean_squared_error: 0.0594
# Epoch 52/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0336 - mean_absolute_error: 0.1410 - mean_squared_error: 0.0336 - val_loss: 0.0576 - val_mean_absolute_error: 0.1865 - val_mean_squared_error: 0.0576
# Epoch 53/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0325 - mean_absolute_error: 0.1357 - mean_squared_error: 0.0325 - val_loss: 0.0588 - val_mean_absolute_error: 0.1876 - val_mean_squared_error: 0.0588
# Epoch 54/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0350 - mean_absolute_error: 0.1463 - mean_squared_error: 0.0350 - val_loss: 0.0581 - val_mean_absolute_error: 0.1817 - val_mean_squared_error: 0.0581
# Epoch 55/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0368 - mean_absolute_error: 0.1459 - mean_squared_error: 0.0368 - val_loss: 0.0634 - val_mean_absolute_error: 0.2030 - val_mean_squared_error: 0.0634
# Epoch 56/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0374 - mean_absolute_error: 0.1514 - mean_squared_error: 0.0374 - val_loss: 0.0631 - val_mean_absolute_error: 0.1852 - val_mean_squared_error: 0.0631
# Epoch 57/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0328 - mean_absolute_error: 0.1400 - mean_squared_error: 0.0328 - val_loss: 0.0691 - val_mean_absolute_error: 0.1909 - val_mean_squared_error: 0.0691
# Epoch 58/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0314 - mean_absolute_error: 0.1405 - mean_squared_error: 0.0314 - val_loss: 0.0603 - val_mean_absolute_error: 0.1817 - val_mean_squared_error: 0.0603
# Epoch 59/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0311 - mean_absolute_error: 0.1365 - mean_squared_error: 0.0311 - val_loss: 0.0570 - val_mean_absolute_error: 0.1823 - val_mean_squared_error: 0.0570
# Epoch 60/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0316 - mean_absolute_error: 0.1354 - mean_squared_error: 0.0316 - val_loss: 0.0607 - val_mean_absolute_error: 0.1975 - val_mean_squared_error: 0.0607
# Epoch 61/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0329 - mean_absolute_error: 0.1415 - mean_squared_error: 0.0329 - val_loss: 0.0579 - val_mean_absolute_error: 0.1834 - val_mean_squared_error: 0.0579
# Epoch 62/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0324 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0324 - val_loss: 0.0627 - val_mean_absolute_error: 0.2053 - val_mean_squared_error: 0.0627
# Epoch 63/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0303 - mean_absolute_error: 0.1328 - mean_squared_error: 0.0303 - val_loss: 0.0627 - val_mean_absolute_error: 0.1969 - val_mean_squared_error: 0.0627
# Epoch 64/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0342 - mean_absolute_error: 0.1449 - mean_squared_error: 0.0342 - val_loss: 0.0637 - val_mean_absolute_error: 0.1939 - val_mean_squared_error: 0.0637
# Epoch 65/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0373 - mean_absolute_error: 0.1492 - mean_squared_error: 0.0373 - val_loss: 0.0586 - val_mean_absolute_error: 0.1933 - val_mean_squared_error: 0.0586
# Epoch 66/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0333 - mean_absolute_error: 0.1420 - mean_squared_error: 0.0333 - val_loss: 0.0772 - val_mean_absolute_error: 0.1994 - val_mean_squared_error: 0.0772
# Epoch 67/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0314 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0314 - val_loss: 0.0650 - val_mean_absolute_error: 0.2054 - val_mean_squared_error: 0.0650
# Epoch 68/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0339 - mean_absolute_error: 0.1386 - mean_squared_error: 0.0339 - val_loss: 0.0626 - val_mean_absolute_error: 0.2058 - val_mean_squared_error: 0.0626
# Epoch 69/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0326 - mean_absolute_error: 0.1407 - mean_squared_error: 0.0326 - val_loss: 0.0577 - val_mean_absolute_error: 0.1793 - val_mean_squared_error: 0.0577
# Epoch 70/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0309 - mean_absolute_error: 0.1348 - mean_squared_error: 0.0309 - val_loss: 0.0555 - val_mean_absolute_error: 0.1848 - val_mean_squared_error: 0.0555
# Epoch 71/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0287 - mean_absolute_error: 0.1312 - mean_squared_error: 0.0287 - val_loss: 0.0609 - val_mean_absolute_error: 0.1833 - val_mean_squared_error: 0.0609
# Epoch 72/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0281 - mean_absolute_error: 0.1278 - mean_squared_error: 0.0281 - val_loss: 0.0656 - val_mean_absolute_error: 0.1859 - val_mean_squared_error: 0.0656
# Epoch 73/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0333 - mean_absolute_error: 0.1394 - mean_squared_error: 0.0333 - val_loss: 0.0623 - val_mean_absolute_error: 0.2034 - val_mean_squared_error: 0.0623
# Epoch 74/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0344 - mean_absolute_error: 0.1454 - mean_squared_error: 0.0344 - val_loss: 0.0632 - val_mean_absolute_error: 0.2047 - val_mean_squared_error: 0.0632
# Epoch 75/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0293 - mean_absolute_error: 0.1334 - mean_squared_error: 0.0293 - val_loss: 0.0655 - val_mean_absolute_error: 0.1854 - val_mean_squared_error: 0.0655
# Epoch 76/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0326 - mean_absolute_error: 0.1409 - mean_squared_error: 0.0326 - val_loss: 0.0601 - val_mean_absolute_error: 0.1820 - val_mean_squared_error: 0.0601
# Epoch 77/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0307 - mean_absolute_error: 0.1340 - mean_squared_error: 0.0307 - val_loss: 0.0664 - val_mean_absolute_error: 0.2148 - val_mean_squared_error: 0.0664
# Epoch 78/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0336 - mean_absolute_error: 0.1411 - mean_squared_error: 0.0336 - val_loss: 0.0569 - val_mean_absolute_error: 0.1902 - val_mean_squared_error: 0.0569
# Epoch 79/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0305 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0305 - val_loss: 0.0734 - val_mean_absolute_error: 0.1936 - val_mean_squared_error: 0.0734
# Epoch 80/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0309 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0309 - val_loss: 0.0612 - val_mean_absolute_error: 0.1821 - val_mean_squared_error: 0.0612
# Epoch 81/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0279 - mean_absolute_error: 0.1311 - mean_squared_error: 0.0279 - val_loss: 0.0682 - val_mean_absolute_error: 0.1920 - val_mean_squared_error: 0.0682
# Epoch 82/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0349 - mean_absolute_error: 0.1475 - mean_squared_error: 0.0349 - val_loss: 0.0564 - val_mean_absolute_error: 0.1877 - val_mean_squared_error: 0.0564
# Epoch 83/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0360 - mean_absolute_error: 0.1472 - mean_squared_error: 0.0360 - val_loss: 0.0679 - val_mean_absolute_error: 0.2198 - val_mean_squared_error: 0.0679
# Epoch 84/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0348 - mean_absolute_error: 0.1457 - mean_squared_error: 0.0348 - val_loss: 0.0574 - val_mean_absolute_error: 0.1757 - val_mean_squared_error: 0.0574
# Epoch 85/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0272 - mean_absolute_error: 0.1243 - mean_squared_error: 0.0272 - val_loss: 0.0581 - val_mean_absolute_error: 0.1882 - val_mean_squared_error: 0.0581
# Epoch 86/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_absolute_error: 0.1323 - mean_squared_error: 0.0291 - val_loss: 0.0577 - val_mean_absolute_error: 0.1841 - val_mean_squared_error: 0.0577
# Epoch 87/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0249 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0249 - val_loss: 0.0610 - val_mean_absolute_error: 0.1819 - val_mean_squared_error: 0.0610
# Epoch 88/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0246 - mean_absolute_error: 0.1191 - mean_squared_error: 0.0246 - val_loss: 0.0718 - val_mean_absolute_error: 0.2281 - val_mean_squared_error: 0.0718
# Epoch 89/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0301 - mean_absolute_error: 0.1367 - mean_squared_error: 0.0301 - val_loss: 0.0616 - val_mean_absolute_error: 0.1985 - val_mean_squared_error: 0.0616
# Epoch 90/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0315 - mean_absolute_error: 0.1394 - mean_squared_error: 0.0315 - val_loss: 0.0628 - val_mean_absolute_error: 0.1850 - val_mean_squared_error: 0.0628
# Epoch 91/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0282 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0282 - val_loss: 0.0587 - val_mean_absolute_error: 0.1977 - val_mean_squared_error: 0.0587
# Epoch 92/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0262 - mean_absolute_error: 0.1236 - mean_squared_error: 0.0262 - val_loss: 0.0682 - val_mean_absolute_error: 0.1890 - val_mean_squared_error: 0.0682
# Epoch 93/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0247 - mean_absolute_error: 0.1210 - mean_squared_error: 0.0247 - val_loss: 0.0575 - val_mean_absolute_error: 0.1788 - val_mean_squared_error: 0.0575
# Epoch 94/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0297 - mean_absolute_error: 0.1315 - mean_squared_error: 0.0297 - val_loss: 0.0735 - val_mean_absolute_error: 0.2286 - val_mean_squared_error: 0.0735
# Epoch 95/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0298 - mean_absolute_error: 0.1311 - mean_squared_error: 0.0298 - val_loss: 0.0571 - val_mean_absolute_error: 0.1807 - val_mean_squared_error: 0.0571
# Epoch 96/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0256 - mean_absolute_error: 0.1214 - mean_squared_error: 0.0256 - val_loss: 0.0572 - val_mean_absolute_error: 0.1912 - val_mean_squared_error: 0.0572
# Epoch 97/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_absolute_error: 0.1279 - mean_squared_error: 0.0266 - val_loss: 0.0572 - val_mean_absolute_error: 0.1838 - val_mean_squared_error: 0.0572
# Epoch 98/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0273 - mean_absolute_error: 0.1261 - mean_squared_error: 0.0273 - val_loss: 0.0606 - val_mean_absolute_error: 0.1850 - val_mean_squared_error: 0.0606
# Epoch 99/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0263 - mean_absolute_error: 0.1230 - mean_squared_error: 0.0263 - val_loss: 0.0621 - val_mean_absolute_error: 0.1914 - val_mean_squared_error: 0.0621
# Epoch 100/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0264 - mean_absolute_error: 0.1252 - mean_squared_error: 0.0264 - val_loss: 0.0623 - val_mean_absolute_error: 0.1894 - val_mean_squared_error: 0.0623

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.xlabel("Epochs")
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.show()

# %%
test_predictions=model.predict(X_test)
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0623 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0623
# [0.062276650220155716, 0.18935531377792358, 0.062276650220155716]

# %% [markdown]
# ### Algorithm no. 04 - Polynomial Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M2, target, test_size=0.2, random_state=0)
deg=2 # Degree 9 is giving the error of insufficient memory
X_train_poly2=PolynomialFeatures(degree=deg).fit_transform(X_train)
X_train_poly2=pd.DataFrame(X_train_poly2)
X_train_poly2=X_train_poly2.drop([0],axis=1)
model5=LinearRegression()
model5.fit(X_train_poly2,y_train)

print('Training data r-square:', model5.score(X_train_poly2, y_train))
X_test_poly2=PolynomialFeatures(degree=deg).fit_transform(X_test)
X_test_poly2=pd.DataFrame(X_test_poly2)
X_test_poly2=X_test_poly2.drop([0],axis=1)
print('Test data r-square:', model5.score(X_test_poly2, y_test))
# print('Number of non-zero features:',np.sum(model5.coef_ != 0))
# Out:
# Training data r-square: 0.9856203584476514
# Test data r-square: 0.6987373033798234

# %% [markdown]
# # Model 3

# %%
Predictor_M3=Predictors.iloc[0:571,0:34]#Slicing
Predictor_M3=Predictor_M3.drop("MT-442", axis=1)
Predictor_M3.head(3)# Only 1st, 2nd & 3rd year Grades.
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
#
#    ME-107  ...  EF-303  HS-304  CS-301  CS-302  TC-383  EL-332  CS-318  \
# 0     1.7  ...     1.7     2.4     3.0     2.0     2.4     2.0     1.7
# 1     1.0  ...     1.0     1.7     3.7     1.4     1.7     2.0     3.7
# 2     3.7  ...     2.4     4.0     3.4     3.7     3.0     3.4     3.7
#
#    CS-306  CS-312  CS-317
# 0     2.0     1.7     1.7
# 1     1.0     1.4     1.0
# 2     3.7     3.0     3.0
#
# [3 rows x 33 columns]

# %% [markdown]
# ### Algorithm no. 01 - Linear Regression

# %%
X_train_M3_lr,X_test_M3_lr,Y_train_M3_lr,Y_test_M3_lr = train_test_split(Predictor_M3, target,test_size=0.2,random_state=5) # Implementing 80 and 20 split
r3=LinearRegression()
r3.fit(X_train_M3_lr,Y_train_M3_lr)
print("The training accuracy", r3.score(X_train_M3_lr,Y_train_M3_lr))
print("The testing accuracy",r3.score(X_test_M3_lr,Y_test_M3_lr))
# Out:
# The training accuracy 0.9380411174884866
# The testing accuracy 0.9321933295381652

# %% [markdown]
# ### Algorithm no. 02 - Regression Tree

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M3, target, test_size=0.3)
rt = DecisionTreeRegressor(criterion = 'mse', max_depth=5)
model_r = rt.fit(X_train, y_train)
y_test_pred = model_r.predict(X_test)
y_train_pred = model_r.predict(X_train)

print('R Squared Score (train) is:', r2_score(y_train, y_train_pred))
print('R Squared Score (test) is:', r2_score(y_test, y_test_pred))
# Out:
# R Squared Score (train) is: 0.9322308466327326
# R Squared Score (test) is: 0.8462339493279843
# E:\Programs\Python310\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# ### Algorithm no. 03 - ANN

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M1, target, test_size=0.2)
model=models.Sequential()
model.add(layers.Dense(64,activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(1,activation='linear'))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['mean_absolute_error','mean_squared_error'])
history = model.fit(X_train,y_train,epochs=100, batch_size=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 46/46 [==============================] - 1s 7ms/step - loss: 3.8616 - mean_absolute_error: 1.2262 - mean_squared_error: 3.8616 - val_loss: 0.1262 - val_mean_absolute_error: 0.2905 - val_mean_squared_error: 0.1262
# Epoch 2/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.1081 - mean_absolute_error: 0.2550 - mean_squared_error: 0.1081 - val_loss: 0.0815 - val_mean_absolute_error: 0.2320 - val_mean_squared_error: 0.0815
# Epoch 3/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0835 - mean_absolute_error: 0.2217 - mean_squared_error: 0.0835 - val_loss: 0.0727 - val_mean_absolute_error: 0.2292 - val_mean_squared_error: 0.0727
# Epoch 4/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0736 - mean_absolute_error: 0.2062 - mean_squared_error: 0.0736 - val_loss: 0.0637 - val_mean_absolute_error: 0.2062 - val_mean_squared_error: 0.0637
# Epoch 5/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0676 - mean_absolute_error: 0.1927 - mean_squared_error: 0.0676 - val_loss: 0.0602 - val_mean_absolute_error: 0.2007 - val_mean_squared_error: 0.0602
# Epoch 6/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0642 - mean_absolute_error: 0.1878 - mean_squared_error: 0.0642 - val_loss: 0.0619 - val_mean_absolute_error: 0.1984 - val_mean_squared_error: 0.0619
# Epoch 7/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0611 - mean_absolute_error: 0.1840 - mean_squared_error: 0.0611 - val_loss: 0.0575 - val_mean_absolute_error: 0.1948 - val_mean_squared_error: 0.0575
# Epoch 8/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0596 - mean_absolute_error: 0.1842 - mean_squared_error: 0.0596 - val_loss: 0.0608 - val_mean_absolute_error: 0.1959 - val_mean_squared_error: 0.0608
# Epoch 9/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0612 - mean_absolute_error: 0.1852 - mean_squared_error: 0.0612 - val_loss: 0.0570 - val_mean_absolute_error: 0.1964 - val_mean_squared_error: 0.0570
# Epoch 10/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0595 - mean_absolute_error: 0.1884 - mean_squared_error: 0.0595 - val_loss: 0.0542 - val_mean_absolute_error: 0.1889 - val_mean_squared_error: 0.0542
# Epoch 11/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0568 - mean_absolute_error: 0.1780 - mean_squared_error: 0.0568 - val_loss: 0.0556 - val_mean_absolute_error: 0.1938 - val_mean_squared_error: 0.0556
# Epoch 12/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0537 - mean_absolute_error: 0.1759 - mean_squared_error: 0.0537 - val_loss: 0.0612 - val_mean_absolute_error: 0.1919 - val_mean_squared_error: 0.0612
# Epoch 13/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0534 - mean_absolute_error: 0.1748 - mean_squared_error: 0.0534 - val_loss: 0.0540 - val_mean_absolute_error: 0.1885 - val_mean_squared_error: 0.0540
# Epoch 14/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0517 - mean_absolute_error: 0.1732 - mean_squared_error: 0.0517 - val_loss: 0.0606 - val_mean_absolute_error: 0.2051 - val_mean_squared_error: 0.0606
# Epoch 15/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0512 - mean_absolute_error: 0.1722 - mean_squared_error: 0.0512 - val_loss: 0.0551 - val_mean_absolute_error: 0.1882 - val_mean_squared_error: 0.0551
# Epoch 16/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0502 - mean_absolute_error: 0.1702 - mean_squared_error: 0.0502 - val_loss: 0.0538 - val_mean_absolute_error: 0.1877 - val_mean_squared_error: 0.0538
# Epoch 17/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0504 - mean_absolute_error: 0.1710 - mean_squared_error: 0.0504 - val_loss: 0.0545 - val_mean_absolute_error: 0.1859 - val_mean_squared_error: 0.0545
# Epoch 18/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0488 - mean_absolute_error: 0.1688 - mean_squared_error: 0.0488 - val_loss: 0.0598 - val_mean_absolute_error: 0.2022 - val_mean_squared_error: 0.0598
# Epoch 19/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0511 - mean_absolute_error: 0.1725 - mean_squared_error: 0.0511 - val_loss: 0.0547 - val_mean_absolute_error: 0.1860 - val_mean_squared_error: 0.0547
# Epoch 20/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0498 - mean_absolute_error: 0.1718 - mean_squared_error: 0.0498 - val_loss: 0.0629 - val_mean_absolute_error: 0.1992 - val_mean_squared_error: 0.0629
# Epoch 21/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0482 - mean_absolute_error: 0.1714 - mean_squared_error: 0.0482 - val_loss: 0.0707 - val_mean_absolute_error: 0.2216 - val_mean_squared_error: 0.0707
# Epoch 22/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0605 - mean_absolute_error: 0.1905 - mean_squared_error: 0.0605 - val_loss: 0.0515 - val_mean_absolute_error: 0.1848 - val_mean_squared_error: 0.0515
# Epoch 23/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0475 - mean_absolute_error: 0.1669 - mean_squared_error: 0.0475 - val_loss: 0.0489 - val_mean_absolute_error: 0.1803 - val_mean_squared_error: 0.0489
# Epoch 24/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0459 - mean_absolute_error: 0.1633 - mean_squared_error: 0.0459 - val_loss: 0.0646 - val_mean_absolute_error: 0.2022 - val_mean_squared_error: 0.0646
# Epoch 25/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0506 - mean_absolute_error: 0.1752 - mean_squared_error: 0.0506 - val_loss: 0.0505 - val_mean_absolute_error: 0.1805 - val_mean_squared_error: 0.0505
# Epoch 26/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0447 - mean_absolute_error: 0.1627 - mean_squared_error: 0.0447 - val_loss: 0.0488 - val_mean_absolute_error: 0.1771 - val_mean_squared_error: 0.0488
# Epoch 27/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0427 - mean_absolute_error: 0.1581 - mean_squared_error: 0.0427 - val_loss: 0.0513 - val_mean_absolute_error: 0.1851 - val_mean_squared_error: 0.0513
# Epoch 28/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0433 - mean_absolute_error: 0.1609 - mean_squared_error: 0.0433 - val_loss: 0.0504 - val_mean_absolute_error: 0.1798 - val_mean_squared_error: 0.0504
# Epoch 29/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0441 - mean_absolute_error: 0.1619 - mean_squared_error: 0.0441 - val_loss: 0.0483 - val_mean_absolute_error: 0.1787 - val_mean_squared_error: 0.0483
# Epoch 30/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0413 - mean_absolute_error: 0.1582 - mean_squared_error: 0.0413 - val_loss: 0.0549 - val_mean_absolute_error: 0.1922 - val_mean_squared_error: 0.0549
# Epoch 31/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0453 - mean_absolute_error: 0.1676 - mean_squared_error: 0.0453 - val_loss: 0.0502 - val_mean_absolute_error: 0.1803 - val_mean_squared_error: 0.0502
# Epoch 32/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0431 - mean_absolute_error: 0.1616 - mean_squared_error: 0.0431 - val_loss: 0.0498 - val_mean_absolute_error: 0.1820 - val_mean_squared_error: 0.0498
# Epoch 33/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0409 - mean_absolute_error: 0.1551 - mean_squared_error: 0.0409 - val_loss: 0.0517 - val_mean_absolute_error: 0.1797 - val_mean_squared_error: 0.0517
# Epoch 34/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0401 - mean_absolute_error: 0.1541 - mean_squared_error: 0.0401 - val_loss: 0.0480 - val_mean_absolute_error: 0.1779 - val_mean_squared_error: 0.0480
# Epoch 35/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0438 - mean_absolute_error: 0.1660 - mean_squared_error: 0.0438 - val_loss: 0.0507 - val_mean_absolute_error: 0.1817 - val_mean_squared_error: 0.0507
# Epoch 36/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0393 - mean_absolute_error: 0.1517 - mean_squared_error: 0.0393 - val_loss: 0.0519 - val_mean_absolute_error: 0.1847 - val_mean_squared_error: 0.0519
# Epoch 37/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0393 - mean_absolute_error: 0.1545 - mean_squared_error: 0.0393 - val_loss: 0.0486 - val_mean_absolute_error: 0.1786 - val_mean_squared_error: 0.0486
# Epoch 38/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0398 - mean_absolute_error: 0.1539 - mean_squared_error: 0.0398 - val_loss: 0.0565 - val_mean_absolute_error: 0.1891 - val_mean_squared_error: 0.0565
# Epoch 39/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0369 - mean_absolute_error: 0.1469 - mean_squared_error: 0.0369 - val_loss: 0.0505 - val_mean_absolute_error: 0.1860 - val_mean_squared_error: 0.0505
# Epoch 40/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0379 - mean_absolute_error: 0.1492 - mean_squared_error: 0.0379 - val_loss: 0.0537 - val_mean_absolute_error: 0.1849 - val_mean_squared_error: 0.0537
# Epoch 41/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0383 - mean_absolute_error: 0.1529 - mean_squared_error: 0.0383 - val_loss: 0.0476 - val_mean_absolute_error: 0.1798 - val_mean_squared_error: 0.0476
# Epoch 42/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_absolute_error: 0.1491 - mean_squared_error: 0.0386 - val_loss: 0.0518 - val_mean_absolute_error: 0.1773 - val_mean_squared_error: 0.0518
# Epoch 43/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0379 - mean_absolute_error: 0.1497 - mean_squared_error: 0.0379 - val_loss: 0.0577 - val_mean_absolute_error: 0.1957 - val_mean_squared_error: 0.0577
# Epoch 44/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0340 - mean_absolute_error: 0.1401 - mean_squared_error: 0.0340 - val_loss: 0.0497 - val_mean_absolute_error: 0.1798 - val_mean_squared_error: 0.0497
# Epoch 45/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0327 - mean_absolute_error: 0.1405 - mean_squared_error: 0.0327 - val_loss: 0.0476 - val_mean_absolute_error: 0.1762 - val_mean_squared_error: 0.0476
# Epoch 46/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0330 - mean_absolute_error: 0.1400 - mean_squared_error: 0.0330 - val_loss: 0.0496 - val_mean_absolute_error: 0.1811 - val_mean_squared_error: 0.0496
# Epoch 47/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0342 - mean_absolute_error: 0.1444 - mean_squared_error: 0.0342 - val_loss: 0.0574 - val_mean_absolute_error: 0.1933 - val_mean_squared_error: 0.0574
# Epoch 48/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0365 - mean_absolute_error: 0.1480 - mean_squared_error: 0.0365 - val_loss: 0.0538 - val_mean_absolute_error: 0.1831 - val_mean_squared_error: 0.0538
# Epoch 49/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0357 - mean_absolute_error: 0.1434 - mean_squared_error: 0.0357 - val_loss: 0.0522 - val_mean_absolute_error: 0.1868 - val_mean_squared_error: 0.0522
# Epoch 50/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0326 - mean_absolute_error: 0.1389 - mean_squared_error: 0.0326 - val_loss: 0.0536 - val_mean_absolute_error: 0.1848 - val_mean_squared_error: 0.0536
# Epoch 51/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0344 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0344 - val_loss: 0.0488 - val_mean_absolute_error: 0.1728 - val_mean_squared_error: 0.0488
# Epoch 52/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0387 - mean_absolute_error: 0.1531 - mean_squared_error: 0.0387 - val_loss: 0.0521 - val_mean_absolute_error: 0.1824 - val_mean_squared_error: 0.0521
# Epoch 53/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0336 - mean_absolute_error: 0.1402 - mean_squared_error: 0.0336 - val_loss: 0.0542 - val_mean_absolute_error: 0.1816 - val_mean_squared_error: 0.0542
# Epoch 54/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0321 - mean_absolute_error: 0.1377 - mean_squared_error: 0.0321 - val_loss: 0.0458 - val_mean_absolute_error: 0.1689 - val_mean_squared_error: 0.0458
# Epoch 55/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0307 - mean_absolute_error: 0.1335 - mean_squared_error: 0.0307 - val_loss: 0.0520 - val_mean_absolute_error: 0.1783 - val_mean_squared_error: 0.0520
# Epoch 56/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0361 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0361 - val_loss: 0.0467 - val_mean_absolute_error: 0.1771 - val_mean_squared_error: 0.0467
# Epoch 57/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0302 - mean_absolute_error: 0.1359 - mean_squared_error: 0.0302 - val_loss: 0.0504 - val_mean_absolute_error: 0.1740 - val_mean_squared_error: 0.0504
# Epoch 58/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0312 - mean_absolute_error: 0.1344 - mean_squared_error: 0.0312 - val_loss: 0.0518 - val_mean_absolute_error: 0.1814 - val_mean_squared_error: 0.0518
# Epoch 59/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0327 - mean_absolute_error: 0.1402 - mean_squared_error: 0.0327 - val_loss: 0.0530 - val_mean_absolute_error: 0.1834 - val_mean_squared_error: 0.0530
# Epoch 60/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0340 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0340 - val_loss: 0.0622 - val_mean_absolute_error: 0.1901 - val_mean_squared_error: 0.0622
# Epoch 61/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0288 - mean_absolute_error: 0.1302 - mean_squared_error: 0.0288 - val_loss: 0.0541 - val_mean_absolute_error: 0.1873 - val_mean_squared_error: 0.0541
# Epoch 62/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0299 - mean_absolute_error: 0.1293 - mean_squared_error: 0.0299 - val_loss: 0.0543 - val_mean_absolute_error: 0.1834 - val_mean_squared_error: 0.0543
# Epoch 63/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0302 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0302 - val_loss: 0.0540 - val_mean_absolute_error: 0.1837 - val_mean_squared_error: 0.0540
# Epoch 64/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0321 - mean_absolute_error: 0.1375 - mean_squared_error: 0.0321 - val_loss: 0.0508 - val_mean_absolute_error: 0.1778 - val_mean_squared_error: 0.0508
# Epoch 65/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0299 - mean_absolute_error: 0.1317 - mean_squared_error: 0.0299 - val_loss: 0.0670 - val_mean_absolute_error: 0.2035 - val_mean_squared_error: 0.0670
# Epoch 66/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0274 - mean_absolute_error: 0.1263 - mean_squared_error: 0.0274 - val_loss: 0.0532 - val_mean_absolute_error: 0.1853 - val_mean_squared_error: 0.0532
# Epoch 67/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0303 - mean_absolute_error: 0.1328 - mean_squared_error: 0.0303 - val_loss: 0.0538 - val_mean_absolute_error: 0.1857 - val_mean_squared_error: 0.0538
# Epoch 68/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0288 - mean_absolute_error: 0.1309 - mean_squared_error: 0.0288 - val_loss: 0.0474 - val_mean_absolute_error: 0.1726 - val_mean_squared_error: 0.0474
# Epoch 69/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0315 - mean_absolute_error: 0.1356 - mean_squared_error: 0.0315 - val_loss: 0.0473 - val_mean_absolute_error: 0.1749 - val_mean_squared_error: 0.0473
# Epoch 70/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0330 - mean_absolute_error: 0.1388 - mean_squared_error: 0.0330 - val_loss: 0.0724 - val_mean_absolute_error: 0.2064 - val_mean_squared_error: 0.0724
# Epoch 71/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0321 - mean_absolute_error: 0.1398 - mean_squared_error: 0.0321 - val_loss: 0.0602 - val_mean_absolute_error: 0.1917 - val_mean_squared_error: 0.0602
# Epoch 72/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0265 - mean_absolute_error: 0.1253 - mean_squared_error: 0.0265 - val_loss: 0.0538 - val_mean_absolute_error: 0.1812 - val_mean_squared_error: 0.0538
# Epoch 73/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0280 - mean_absolute_error: 0.1299 - mean_squared_error: 0.0280 - val_loss: 0.0535 - val_mean_absolute_error: 0.1862 - val_mean_squared_error: 0.0535
# Epoch 74/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0288 - mean_absolute_error: 0.1293 - mean_squared_error: 0.0288 - val_loss: 0.0542 - val_mean_absolute_error: 0.1781 - val_mean_squared_error: 0.0542
# Epoch 75/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0300 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0300 - val_loss: 0.0504 - val_mean_absolute_error: 0.1765 - val_mean_squared_error: 0.0504
# Epoch 76/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0283 - mean_absolute_error: 0.1289 - mean_squared_error: 0.0283 - val_loss: 0.0538 - val_mean_absolute_error: 0.1838 - val_mean_squared_error: 0.0538
# Epoch 77/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_absolute_error: 0.1199 - mean_squared_error: 0.0254 - val_loss: 0.0517 - val_mean_absolute_error: 0.1786 - val_mean_squared_error: 0.0517
# Epoch 78/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0321 - mean_absolute_error: 0.1366 - mean_squared_error: 0.0321 - val_loss: 0.0533 - val_mean_absolute_error: 0.1853 - val_mean_squared_error: 0.0533
# Epoch 79/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0276 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0276 - val_loss: 0.0554 - val_mean_absolute_error: 0.1904 - val_mean_squared_error: 0.0554
# Epoch 80/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0288 - mean_absolute_error: 0.1300 - mean_squared_error: 0.0288 - val_loss: 0.0529 - val_mean_absolute_error: 0.1786 - val_mean_squared_error: 0.0529
# Epoch 81/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0315 - mean_absolute_error: 0.1362 - mean_squared_error: 0.0315 - val_loss: 0.0602 - val_mean_absolute_error: 0.1920 - val_mean_squared_error: 0.0602
# Epoch 82/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0310 - mean_absolute_error: 0.1347 - mean_squared_error: 0.0310 - val_loss: 0.0539 - val_mean_absolute_error: 0.1846 - val_mean_squared_error: 0.0539
# Epoch 83/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0285 - mean_absolute_error: 0.1278 - mean_squared_error: 0.0285 - val_loss: 0.0520 - val_mean_absolute_error: 0.1807 - val_mean_squared_error: 0.0520
# Epoch 84/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0323 - mean_absolute_error: 0.1393 - mean_squared_error: 0.0323 - val_loss: 0.0601 - val_mean_absolute_error: 0.1895 - val_mean_squared_error: 0.0601
# Epoch 85/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0300 - mean_absolute_error: 0.1335 - mean_squared_error: 0.0300 - val_loss: 0.0728 - val_mean_absolute_error: 0.2084 - val_mean_squared_error: 0.0728
# Epoch 86/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0261 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0261 - val_loss: 0.0546 - val_mean_absolute_error: 0.1863 - val_mean_squared_error: 0.0546
# Epoch 87/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0237 - mean_absolute_error: 0.1143 - mean_squared_error: 0.0237 - val_loss: 0.0650 - val_mean_absolute_error: 0.2086 - val_mean_squared_error: 0.0650
# Epoch 88/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_absolute_error: 0.1299 - mean_squared_error: 0.0291 - val_loss: 0.0550 - val_mean_absolute_error: 0.1884 - val_mean_squared_error: 0.0550
# Epoch 89/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0257 - mean_absolute_error: 0.1228 - mean_squared_error: 0.0257 - val_loss: 0.0556 - val_mean_absolute_error: 0.1845 - val_mean_squared_error: 0.0556
# Epoch 90/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0296 - mean_absolute_error: 0.1319 - mean_squared_error: 0.0296 - val_loss: 0.0724 - val_mean_absolute_error: 0.2236 - val_mean_squared_error: 0.0724
# Epoch 91/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0324 - mean_absolute_error: 0.1392 - mean_squared_error: 0.0324 - val_loss: 0.0561 - val_mean_absolute_error: 0.1959 - val_mean_squared_error: 0.0561
# Epoch 92/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0281 - mean_absolute_error: 0.1295 - mean_squared_error: 0.0281 - val_loss: 0.0526 - val_mean_absolute_error: 0.1848 - val_mean_squared_error: 0.0526
# Epoch 93/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0244 - mean_absolute_error: 0.1194 - mean_squared_error: 0.0244 - val_loss: 0.0622 - val_mean_absolute_error: 0.2031 - val_mean_squared_error: 0.0622
# Epoch 94/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0304 - mean_absolute_error: 0.1349 - mean_squared_error: 0.0304 - val_loss: 0.0594 - val_mean_absolute_error: 0.1919 - val_mean_squared_error: 0.0594
# Epoch 95/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0228 - mean_absolute_error: 0.1130 - mean_squared_error: 0.0228 - val_loss: 0.0559 - val_mean_absolute_error: 0.1907 - val_mean_squared_error: 0.0559
# Epoch 96/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0251 - mean_absolute_error: 0.1204 - mean_squared_error: 0.0251 - val_loss: 0.0593 - val_mean_absolute_error: 0.1953 - val_mean_squared_error: 0.0593
# Epoch 97/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0270 - mean_absolute_error: 0.1265 - mean_squared_error: 0.0270 - val_loss: 0.0571 - val_mean_absolute_error: 0.1865 - val_mean_squared_error: 0.0571
# Epoch 98/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_absolute_error: 0.1135 - mean_squared_error: 0.0231 - val_loss: 0.0528 - val_mean_absolute_error: 0.1823 - val_mean_squared_error: 0.0528
# Epoch 99/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0258 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0258 - val_loss: 0.0636 - val_mean_absolute_error: 0.2054 - val_mean_squared_error: 0.0636
# Epoch 100/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0250 - mean_absolute_error: 0.1201 - mean_squared_error: 0.0250 - val_loss: 0.0531 - val_mean_absolute_error: 0.1815 - val_mean_squared_error: 0.0531

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.xlabel("Epochs")
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.show()

# %%
test_predictions=model.predict(X_test)
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0531 - mean_absolute_error: 0.1815 - mean_squared_error: 0.0531
# [0.05308942124247551, 0.18148569762706757, 0.05308942124247551]

# %% [markdown]
# ### Algorithm no. 04 - Polynomial Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(Predictor_M3, target, test_size=0.2, random_state=10)
deg=3 # Degree 9 is giving the error of insufficient memory
X_train_poly2=PolynomialFeatures(degree=deg).fit_transform(X_train)
X_train_poly2=pd.DataFrame(X_train_poly2)
X_train_poly2=X_train_poly2.drop([0],axis=1)
model5=LinearRegression()
model5.fit(X_train_poly2,y_train)

print('Training data r-square:', model5.score(X_train_poly2, y_train))
X_test_poly2=PolynomialFeatures(degree=deg).fit_transform(X_test)
X_test_poly2=pd.DataFrame(X_test_poly2)
X_test_poly2=X_test_poly2.drop([0],axis=1)
print('Test data r-square:', model5.score(X_test_poly2, y_test))
# print('Number of non-zero features:',np.sum(model5.coef_ != 0))
# Out:
# Training data r-square: 1.0
# Test data r-square: 0.9163396484232182

# %% [markdown]
# ## Interface.

# %%
#imports 
import warnings
warnings.filterwarnings('ignore')

import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
# Student information block
file = open("reportcard.jpg", "rb")
image = file.read()

image_headline = widgets.Image(
                    value=image,
                    format='jpg',
                    width='200',
                    height='300'
                )

label_headline = widgets.Label(
                    style={'description_width': 'initial'},
                    value='WELCOME TO CGPA PREDICTION MODEL'
                )

Student_Name=widgets.Text(
    placeholder='Enter Full Name',
    description='Name:',
    disabled=False
)

Seat_No=widgets.Text(
    placeholder='Enter Seat No',
    description='Seat No:',
    disabled=False
)

Student_Year=widgets.Dropdown(
    options=['1st year', '1st & 2nd year', '1st, 2nd & 3rd year'],
    value=None,
    description='Year:',
    disabled=False,
)
vbox_headline = widgets.VBox([image_headline, label_headline,Student_Name,Seat_No,Student_Year])
display(vbox_headline)
# Out:
# VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\…

# %%
enco_list=[('A+', 4.0), ('A', 4.0), ('A-',3.7), ('B+',3.4), ('B',3.0), ('B-',2.7), ('C+',2.4), ('C',2.0), ('C-',1.7),('D+',1.4), ('D',1.0), ('F',0.0), ('WU',0.0), ('W',0.0), ('I',0.0)]

print("Please Click the 'Fill Grades' Button to fill your", Student_Year.value, "Grades")
button_send = widgets.Button(
                description='Fill Grades',
                tooltip='Send',
                style={'description_width': 'initial'}
            )

output = widgets.Output()

def on_button_clicked(event):
    with output:
            if Student_Year.value=='1st year':
                print("        **** First Year Courses ******     ")
                PH_121=widgets.Dropdown(
                options=enco_list,
                description='PH-121',
                )
                HS_101=widgets.Dropdown(
                    options=enco_list,
                    description='HS-101',
                )   
                CY_105=widgets.Dropdown(
                    options=enco_list,
                    description='CY-105',
                )   
                HS_105_12=widgets.Dropdown(
                    options=enco_list,
                    description='HS_105/12',
                )   
                MT_111=widgets.Dropdown(
                    options=enco_list,
                    description='MT-111',
                )   
                CS_105=widgets.Dropdown(
                options=enco_list,
                description='CS-105',
                )   
                CS_106=widgets.Dropdown(
                    options=enco_list,
                    description='CS-106',
                )
                EL_102=widgets.Dropdown(
                    options=enco_list,
                    description='EL-102',
                )   
                EE_119=widgets.Dropdown(
                    options=enco_list,
                    description='EE-119',
                )   
                ME_107=widgets.Dropdown(
                    options=enco_list,
                    description='ME-107',
                )
                CS_107=widgets.Dropdown(
                    options=enco_list,
                    description='CS-107',
                )
                vboxM1_text = widgets.VBox([PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107, CS_107])
                display(vboxM1_text)

            elif Student_Year.value=='1st & 2nd year':
                print("        **** First Year Courses ******     ")
                PH_121=widgets.Dropdown(
                options=enco_list,
                description='PH-121',
                )
                HS_101=widgets.Dropdown(
                    options=enco_list,
                    description='HS-101',
                )   
                CY_105=widgets.Dropdown(
                    options=enco_list,
                    description='CY-105',
                )   
                HS_105_12=widgets.Dropdown(
                    options=enco_list,
                    description='HS_105/12',
                )   
                MT_111=widgets.Dropdown(
                    options=enco_list,
                    description='MT-111',
                )   
                CS_105=widgets.Dropdown(
                    options=enco_list,
                    description='CS-105',
                )   
                CS_106=widgets.Dropdown(
                    options=enco_list,
                    description='CS-106',
                )
                EL_102=widgets.Dropdown(
                    options=enco_list,
                    description='EL-102',
                )   
                EE_119=widgets.Dropdown(
                    options=enco_list,
                    description='EE-119',
                )   
                ME_107=widgets.Dropdown(
                    options=enco_list,
                    description='ME-107',
                )
                CS_107=widgets.Dropdown(
                    options=enco_list,
                    description='CS-107',
                )
                print("        **** Second Year Courses ******     ")
                HS_205_20=widgets.Dropdown(
                    options=enco_list,
                    description='HS-205/20',
                )
                MT_222=widgets.Dropdown(
                    options=enco_list,
                    description='MT-222',
                )
                EE_222=widgets.Dropdown(
                    options=enco_list,
                    description='EE-222',
                )
                MT_224=widgets.Dropdown(
                    options=enco_list,
                    description='MT-224',
                )
                CS_210=widgets.Dropdown(
                    options=enco_list,
                    description='CS-210',
                )
                CS_211=widgets.Dropdown(
                    options=enco_list,
                    description='CS-211',
                )
                CS_203=widgets.Dropdown(
                    options=enco_list,
                    description='CS-203',
                )
                CS_214=widgets.Dropdown(
                    options=enco_list,
                    description='CS-214',
                )
                EE_217=widgets.Dropdown(
                    options=enco_list,
                    description='EE-217',
                )
                CS_212=widgets.Dropdown(
                    options=enco_list,
                    description='CS-212',
                )
                CS_215=widgets.Dropdown(
                    options=enco_list,
                    description='CS-215',
                ) 
                vboxM2_text = widgets.VBox([PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107,CS_107, HS_205_20,MT_222,EE_222,MT_224,CS_210,CS_211,CS_203,CS_214,EE_217,CS_212,CS_215])
                display(vboxM2_text)

            if Student_Year.value=='1st, 2nd & 3rd year':
                print("        **** First Year Courses ******     ")
                PH_121=widgets.Dropdown(
                options=enco_list,
                description='PH-121',
                )
                HS_101=widgets.Dropdown(
                    options=enco_list,
                    description='HS-101',
                )   
                CY_105=widgets.Dropdown(
                    options=enco_list,
                    description='CY-105',
                )   
                HS_105_12=widgets.Dropdown(
                    options=enco_list,
                    description='HS_105/12',
                )   
                MT_111=widgets.Dropdown(
                    options=enco_list,
                    description='MT-111',
                )   
                CS_105=widgets.Dropdown(
                options=enco_list,
                description='CS-105',
                )   
                CS_106=widgets.Dropdown(
                    options=enco_list,
                    description='CS-106',
                )
                EL_102=widgets.Dropdown(
                    options=enco_list,
                    description='EL-102',
                )   
                EE_119=widgets.Dropdown(
                    options=enco_list,
                    description='EE-119',
                )   
                ME_107=widgets.Dropdown(
                    options=enco_list,
                    description='ME-107',
                )
                CS_107=widgets.Dropdown(
                    options=enco_list,
                    description='CS-107',
                )
                print("        **** Second Year Courses ******     ")
                HS_205_20=widgets.Dropdown(
                    options=enco_list,
                    description='HS-205/20',
                )
                MT_222=widgets.Dropdown(
                    options=enco_list,
                    description='MT-222',
                )
                EE_222=widgets.Dropdown(
                    options=enco_list,
                    description='EE-222',
                )
                MT_224=widgets.Dropdown(
                    options=enco_list,
                    description='MT-224',
                )
                CS_210=widgets.Dropdown(
                    options=enco_list,
                    description='CS-210',
                )
                CS_211=widgets.Dropdown(
                    options=enco_list,
                    description='CS-211',
                )
                CS_203=widgets.Dropdown(
                    options=enco_list,
                    description='CS-203',
                )
                CS_214=widgets.Dropdown(
                    options=enco_list,
                    description='CS-214',
                )
                EE_217=widgets.Dropdown(
                    options=enco_list,
                    description='EE-217',
                )
                CS_212=widgets.Dropdown(
                    options=enco_list,
                    description='CS-212',
                )
                CS_215=widgets.Dropdown(
                    options=enco_list,
                    description='CS-215',
                ) 
                print("        **** Third Year Courses ******     ")
                MT_331=widgets.Dropdown(
                    options=enco_list,
                    description='MT-331',
                ) 
                EF_303=widgets.Dropdown(
                    options=enco_list,
                    description='EF-303',
                ) 
                HS_304=widgets.Dropdown(
                    options=enco_list,
                    description='HS-304',
                ) 
                CS_301=widgets.Dropdown(
                    options=enco_list,
                    description='CS-301',
                ) 
                CS_302=widgets.Dropdown(
                    options=enco_list,
                    description='CS-302',
                ) 
                TC_383=widgets.Dropdown(
                    options=enco_list,
                    description='TC-383',
                )
                EL_332=widgets.Dropdown(
                    options=enco_list,
                    description='EL-332',
                )
                CS_318=widgets.Dropdown(
                    options=enco_list,
                    description='CS-318',
                )
                CS_306=widgets.Dropdown(
                    options=enco_list,
                    description='CS-306',
                )
                CS_312=widgets.Dropdown(
                    options=enco_list,
                    description='CS-312',
                )
                CS_317=widgets.Dropdown(
                    options=enco_list,
                    description='CS-317',
                )

                vboxM3_text = widgets.VBox([PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107,CS_107, HS_205_20,MT_222,EE_222,MT_224,CS_210,CS_211,CS_203,CS_214,EE_217,CS_212,CS_215,MT_331,EF_303,HS_304,CS_301,CS_302,TC_383,EL_332,CS_318,CS_306,CS_312,CS_317])
                display(vboxM3_text)
            
            print("Please Click the 'Submit Grades' Button to submit your Grades")
            button_send_G = widgets.Button(
                            description='Submit Grades',
                            tooltip='Send',
                            style={'description_width': 'initial'}
                        )

            output_G = widgets.Output()

            def on_button_clicked(event):
                with output_G:
                    clear_output()
                    grade_list1=[]
                    grade_list2=[]
                    grade_list3=[]
                    if Student_Year.value=='1st year':
                        for element in [PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107, CS_107]:
                            grade_list1.append(element.value)
                        print('Following is your GPAs of the grades submitted')
                        print(', '.join(map(str, grade_list1)))
                        print('\n')
                        print("Please Click the 'Predict CGPA' Button to display your CGPA")

                    if Student_Year.value=='1st & 2nd year':
                        for element in [PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107,CS_107, HS_205_20,MT_222,EE_222,MT_224,CS_210,CS_211,CS_203,CS_214,EE_217,CS_212,CS_215]:
                            grade_list2.append(element.value)
                        print('Following is your GPAs of the grades submitted')
                        print(', '.join(map(str, grade_list2)))
                        print('\n')
                        print("Please Click the 'Predict CGPA' Button to display your CGPA")

                    if Student_Year.value=='1st, 2nd & 3rd year':
                        for element in [PH_121, HS_101, CY_105, HS_105_12, MT_111, CS_105, CS_106, EL_102, EE_119, ME_107,CS_107, HS_205_20,MT_222,EE_222,MT_224,CS_210,CS_211,CS_203,CS_214,EE_217,CS_212,CS_215,MT_331,EF_303,HS_304,CS_301,CS_302,TC_383,EL_332,CS_318,CS_306,CS_312,CS_317]:
                            grade_list3.append(element.value)
                        print('Following is your GPAs of the grades submitted')
                        print(', '.join(map(str, grade_list3)))
                        print('\n')
                        print("Please Click the 'Predict CGPA' Button to display your CGPA")

                    button_send_P = widgets.Button(
                                    description='Predict CGPA',
                                    tooltip='Send',
                                    style={'description_width': 'initial'}
                                )
                    output_P = widgets.Output()

                    def on_button_clicked(event):
                        with output_P:
                            clear_output()
                            if Student_Year.value=='1st year':
                                lst1=[]
                                lst1.append(grade_list1)
                                df1 = pd.DataFrame (lst1, columns = ['PH-121', 'HS-101','CY-105','HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107', 'CS-107'])
                                y_pred1 = r1.predict(df1)
                                print("The Predicted CGPA of",Student_Name.value, ',',Seat_No.value,"on the basis of",Student_Year.value,"is"  ,round(y_pred1[0], 2))

                            if Student_Year.value=='1st & 2nd year':
                                lst2=[]
                                lst2.append(grade_list2)
                                df2 = pd.DataFrame (lst2, columns = ['PH-121', 'HS-101','CY-105','HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107','CS-107','HS-205/20','MT-222','EE-222','MT-224','CS-210','CS-211','CS-203','CS-214','EE-217','CS-212','CS-215'])
                                y_pred1 = r2.predict(df2)
#                                 print(y_pred1[0])
                                print("The Predicted CGPA of",Student_Name.value, ',',Seat_No.value,"on the basis of",Student_Year.value,"is"  ,round(y_pred1[0],2))

                            if Student_Year.value=='1st, 2nd & 3rd year':
                                lst3=[]
                                lst3.append(grade_list3)
                                df3 = pd.DataFrame (lst3, columns = ['PH-121', 'HS-101','CY-105','HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107','CS-107','HS-205/20','MT-222','EE-222','MT-224','CS-210','CS-211','CS-203','CS-214','EE-217','CS-212','CS-215','MT-331','EF-303','HS-304','CS-301','CS-302','TC-383','EL-332','CS-318','CS-306','CS-312','CS-317'])
                                y_pred1 = r3.predict(df3)
#                                 print(y_pred1[0])
                                print("The Predicted CGPA of",Student_Name.value, ',',Seat_No.value,"on the basis of",Student_Year.value,"is"  ,round(y_pred1[0],2))

########################### third button for confirming info ############################

                    button_send_P.on_click(on_button_clicked)

                    vbox_result_P = widgets.VBox([button_send_P, output_P])
                    display(vbox_result_P)
                    

########################### second button for confirming info ############################
            button_send_G.on_click(on_button_clicked)

            vbox_result_G = widgets.VBox([button_send_G, output_G])
            display(vbox_result_G)
            

########################### first button for confirming info ############################

button_send.on_click(on_button_clicked)

vbox_result = widgets.VBox([button_send, output])
display(vbox_result)
# Out:
# Please Click the 'Fill Grades' Button to fill your None Grades
# VBox(children=(Button(description='Fill Grades', style=ButtonStyle(), tooltip='Send'), Output()))

# %%
import pickle
# import dill as pickle
#pickling
data = {"model1": r1,"model2": r2,"model3": r3}

with open('interface.pkl', 'wb') as file:
    pickle.dump(data, file)
with open('interface.pkl', 'rb') as file:
    data = pickle.load(file)
